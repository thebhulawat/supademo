# %%
# %%capture --no-stderr
# %pip install -U --quiet langgraph langsmith langchain_openai langchainhub langchain_core langchain_community langchain 
# %pip install --upgrade --quiet  playwright > /dev/null
# !playwright install

# %%
# Optional: add tracing to visualize the agent trajectories
import os
from getpass import getpass


def _getpass(env_var: str):
    if not os.environ.get(env_var):
        os.environ[env_var] = getpass(f"{env_var}=")


os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "Web-Voyager"
_getpass("LANGCHAIN_API_KEY")
_getpass("OPENAI_API_KEY")

# %%
import nest_asyncio

# This is just required for running async playwright in a Jupyter notebook
nest_asyncio.apply()

# %%
from typing import List, Optional, TypedDict

from langchain_core.messages import BaseMessage, SystemMessage
from playwright.async_api import Page


class BBox(TypedDict):
    x: float
    y: float
    text: str
    type: str
    ariaLabel: str


class Prediction(TypedDict):
    action: str
    args: Optional[List[str]]


# This represents the state of the agent
# as it proceeds through execution
class AgentState(TypedDict):
    page: Page  # The Playwright web page lets us interact with the web environment
    input: str  # User request
    img: str  # b64 encoded screenshot
    bboxes: List[BBox]  # The bounding boxes from the browser annotation function
    prediction: Prediction  # The Agent's output
    # A system message (or messages) containing the intermediate steps
    scratchpad: List[BaseMessage]
    observation: str  # The most recent response from a tool

# %%
import asyncio
import platform


async def click(state: AgentState):
    # - Click [Numerical_Label]
    page = state["page"]
    click_args = state["prediction"]["args"]
    if click_args is None or len(click_args) != 1:
        return f"Failed to click bounding box labeled as number {click_args}"
    bbox_id = click_args[0]
    bbox_id = int(bbox_id)
    try:
        bbox = state["bboxes"][bbox_id]
    except Exception:
        return f"Error: no bbox for : {bbox_id}"
    x, y = bbox["x"], bbox["y"]
    await page.mouse.click(x, y)
    # TODO: In the paper, they automatically parse any downloaded PDFs
    # We could add something similar here as well and generally
    # improve response format.
    return f"Clicked {bbox_id}"


async def type_text(state: AgentState):
    page = state["page"]
    type_args = state["prediction"]["args"]
    if type_args is None or len(type_args) != 2:
        return (
            f"Failed to type in element from bounding box labeled as number {type_args}"
        )
    bbox_id = type_args[0]
    bbox_id = int(bbox_id)
    bbox = state["bboxes"][bbox_id]
    x, y = bbox["x"], bbox["y"]
    text_content = type_args[1]
    await page.mouse.click(x, y)
    # Check if MacOS
    select_all = "Meta+A" if platform.system() == "Darwin" else "Control+A"
    await page.keyboard.press(select_all)
    await page.keyboard.press("Backspace")
    await page.keyboard.type(text_content)
    await page.keyboard.press("Enter")
    return f"Typed {text_content} and submitted"


# async def scroll(state: AgentState):
    page = state["page"]
    scroll_args = state["prediction"]["args"]
    if scroll_args is None or len(scroll_args) != 2:
        return "Failed to scroll due to incorrect arguments."

    target, direction = scroll_args

    if target.upper() == "WINDOW":
        # Not sure the best value for this:
        scroll_amount = 500
        scroll_direction = (
            -scroll_amount if direction.lower() == "up" else scroll_amount
        )
        await page.evaluate(f"window.scrollBy(0, {scroll_direction})")
    else:
        # Scrolling within a specific element
        scroll_amount = 200
        target_id = int(target)
        bbox = state["bboxes"][target_id]
        x, y = bbox["x"], bbox["y"]
        scroll_direction = (
            -scroll_amount if direction.lower() == "up" else scroll_amount
        )
        await page.mouse.move(x, y)
        await page.mouse.wheel(0, scroll_direction)

    return f"Scrolled {direction} in {'window' if target.upper() == 'WINDOW' else 'element'}"

async def scroll(state: AgentState):
    page = state["page"]
    scroll_args = state["prediction"]["args"]
    if scroll_args is None or len(scroll_args) != 2:
        return "Failed to scroll due to incorrect arguments."

    target, direction = scroll_args

    if target.upper() == "WINDOW":
        # Scrolling the entire window
        scroll_amount = 500
        scroll_direction = -scroll_amount if direction.lower() == "up" else scroll_amount
        await page.evaluate(f"window.scrollBy(0, {scroll_direction})")
        return f"Scrolled {direction} in window"
    else:
        # Scrolling within a specific element
        try:
            target_id = int(target)
            if target_id < 0 or target_id >= len(state["bboxes"]):
                return f"Error: Invalid bounding box ID {target_id}. Valid range is 0 to {len(state['bboxes']) - 1}."
            
            bbox = state["bboxes"][target_id]
            x, y = bbox["x"], bbox["y"]
            scroll_amount = 200
            scroll_direction = -scroll_amount if direction.lower() == "up" else scroll_amount
            await page.mouse.move(x, y)
            await page.mouse.wheel(0, scroll_direction)
            return f"Scrolled {direction} in element {target_id}"
        except ValueError:
            return f"Error: Invalid target '{target}'. Expected 'WINDOW' or a number."

async def wait(state: AgentState):
    sleep_time = 5
    await asyncio.sleep(sleep_time)
    return f"Waited for {sleep_time}s."


async def go_back(state: AgentState):
    page = state["page"]
    await page.go_back()
    return f"Navigated back a page to {page.url}."


async def to_google(state: AgentState):
    page = state["page"]
    await page.goto("https://www.google.com/")
    return "Navigated to google.com."


async def open_new_tab(state: AgentState):
    browser = state["page"].context.browser
    new_page = await browser.new_page()
    state["page"] = new_page
    return "Opened a new tab."


async def switch_to_previous_tab(state: AgentState):
    context = state["page"].context
    pages = context.pages
    current_index = pages.index(state["page"])
    if current_index > 0:
        state["page"] = pages[current_index - 1]
        return f"Switched to the previous tab (index: {current_index - 1})."
    else:
        return "Already on the first tab. No previous tab to switch to."

# %%
import base64

from langchain_core.runnables import chain as chain_decorator

# Some javascript we will run on each step
# to take a screenshot of the page, select the
# elements to annotate, and add bounding boxes
with open("original_mark_page.js") as f:
    mark_page_script = f.read()


# @chain_decorator
# async def mark_page(page):
#     await page.evaluate(mark_page_script)
#     for _ in range(10):
#         try:
#             bboxes = await page.evaluate("markPage()")
#             break
#         except Exception:
#             # May be loading...
#             asyncio.sleep(3)
#     screenshot = await page.screenshot()
#     # Ensure the bboxes don't follow us around
#     await page.evaluate("unmarkPage()")
#     return {
#         "img": base64.b64encode(screenshot).decode(),
#         "bboxes": bboxes,
#     }

@chain_decorator
async def mark_page(page):
    await page.evaluate(mark_page_script)
    bboxes = None
    for _ in range(10):
        try:
            bboxes = await page.evaluate("markPage()")
            break
        except Exception:
            await asyncio.sleep(3)
    
    if bboxes is None:
        raise Exception("Failed to get bounding boxes after multiple attempts")
    
    screenshot = await page.screenshot()
    # Ensure the bboxes don't follow us around
    await page.evaluate("unmarkPage()")
    return {
        "img": base64.b64encode(screenshot).decode(),
        "bboxes": bboxes,
    }

# %%
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI


async def annotate(state):
    marked_page = await mark_page.with_retry().ainvoke(state["page"])
    return {**state, **marked_page}


def format_descriptions(state):
    labels = []
    for i, bbox in enumerate(state["bboxes"]):
        text = bbox.get("ariaLabel") or ""
        if not text.strip():
            text = bbox["text"]
        el_type = bbox.get("type")
        labels.append(f'{i} (<{el_type}/>): "{text}"')
    bbox_descriptions = "\nValid Bounding Boxes:\n" + "\n".join(labels)
    return {**state, "bbox_descriptions": bbox_descriptions}


def parse(text: str) -> dict:
    action_prefix = "Action: "
    if not text.strip().split("\n")[-1].startswith(action_prefix):
        return {"action": "retry", "args": f"Could not parse LLM Output: {text}"}
    action_block = text.strip().split("\n")[-1]

    action_str = action_block[len(action_prefix) :]
    split_output = action_str.split(" ", 1)
    if len(split_output) == 1:
        action, action_input = split_output[0], None
    else:
        action, action_input = split_output
    action = action.strip()
    if action_input is not None:
        action_input = [
            inp.strip().strip("[]") for inp in action_input.strip().split(";")
        ]
    return {"action": action, "args": action_input}


# Will need a later version of langchain to pull
# this image prompt template
prompt = hub.pull("nischal/supademo")
prompt.partial_variables={'scratchpad': []}
prompt.input_variables=['bbox_descriptions', 'img', 'input']

# %%
prompt2 = hub.pull("wfh/web-voyager")
print(prompt)
print(prompt2)
# Out:
# input_variables=['bbox_descriptions', 'img', 'input'] input_types={'scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]} partial_variables={'scratchpad': []} metadata={'lc_hub_owner': 'nischal', 'lc_hub_repo': 'supademo', 'lc_hub_commit_hash': '155e2a487bb7b2d337e45ed122f8f50fa4b79a8cf647abadfb9c6b3ed76f1e7f'} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], template="Imagine you are a robot browsing the web, just like humans. Now you need to complete a task. In each iteration, you will receive an Observation that includes a screenshot of a webpage and some texts. \nThis screenshot will feature Numerical Labels placed in the TOP LEFT corner of each Web Element. \nCarefully analyze the visual information to identify the Numerical Label corresponding to the Web Element that requires interaction, then follow the guidelines and choose one of the following actions:\n\n1. Click a Web Element.\n2. Delete existing content in a textbox and then type content.\n3. Scroll up or down.\n4. Wait \n5. Go back\n7. Return to google to start over.\n8. Respond with the final answer\n\nCorrespondingly, Action should STRICTLY follow the format:\n\n- Click [Numerical_Label] \n- Type [Numerical_Label]; [Content] \n- Scroll [Numerical_Label or WINDOW]; [up or down] \n- Wait \n- GoBack\n- Google\n- ANSWER; [content]\n\nKey Guidelines You MUST follow:\n\n* Action guidelines *\n1) Execute only one action per iteration.\n2) When clicking or typing, ensure to select the correct bounding box.\n3) Numeric labels lie in the top-left corner of their corresponding bounding boxes and are colored the same.\n\n* Web Browsing Guidelines *\n1) Don't interact with useless web elements like Login, Sign-in, donation that appear in Webpages\n2) Select strategically to minimize time wasted.\n\nYour reply should strictly follow the format:\n\nThought: {{Your brief thoughts (briefly summarize the info that will help ANSWER)}}\nAction: {{One Action format you choose}}\nThen the User will provide:\nObservation: {{A labeled screenshot Given by User}}\n\n")), MessagesPlaceholder(variable_name='scratchpad'), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['bbox_descriptions', 'img', 'input'], template='![img](data:image/png;base64,{img})\n{bbox_descriptions}\n{input}'))]
# input_variables=['bbox_descriptions', 'img', 'input'] input_types={'scratchpad': typing.List[typing.Union[langchain_core.messages.ai.AIMessage, langchain_core.messages.human.HumanMessage, langchain_core.messages.chat.ChatMessage, langchain_core.messages.system.SystemMessage, langchain_core.messages.function.FunctionMessage, langchain_core.messages.tool.ToolMessage]]} partial_variables={'scratchpad': []} metadata={'lc_hub_owner': 'wfh', 'lc_hub_repo': 'web-voyager', 'lc_hub_commit_hash': '8b9276048be8aec78203e8c45c9e15bc3a46e4b3275b05ef727563a2887ebaab'} messages=[SystemMessagePromptTemplate(prompt=[PromptTemplate(input_variables=[], template="Imagine you are a robot browsing the web, just like humans. Now you need to complete a task. In each iteration, you will receive an Observation that includes a screenshot of a webpage and some texts. This screenshot will\nfeature Numerical Labels placed in the TOP LEFT corner of each Web Element. Carefully analyze the visual\ninformation to identify the Numerical Label corresponding to the Web Element that requires interaction, then follow\nthe guidelines and choose one of the following actions:\n\n1. Click a Web Element.\n2. Delete existing content in a textbox and then type content.\n3. Scroll up or down.\n4. Wait \n5. Go back\n7. Return to google to start over.\n8. Respond with the final answer\n\nCorrespondingly, Action should STRICTLY follow the format:\n\n- Click [Numerical_Label] \n- Type [Numerical_Label]; [Content] \n- Scroll [Numerical_Label or WINDOW]; [up or down] \n- Wait \n- GoBack\n- Google\n- ANSWER; [content]\n\nKey Guidelines You MUST follow:\n\n* Action guidelines *\n1) Execute only one action per iteration.\n2) When clicking or typing, ensure to select the correct bounding box.\n3) Numeric labels lie in the top-left corner of their corresponding bounding boxes and are colored the same.\n\n* Web Browsing Guidelines *\n1) Don't interact with useless web elements like Login, Sign-in, donation that appear in Webpages\n2) Select strategically to minimize time wasted.\n\nYour reply should strictly follow the format:\n\nThought: {{Your brief thoughts (briefly summarize the info that will help ANSWER)}}\nAction: {{One Action format you choose}}\nThen the User will provide:\nObservation: {{A labeled screenshot Given by User}}\n")]), MessagesPlaceholder(variable_name='scratchpad', optional=True), HumanMessagePromptTemplate(prompt=[ImagePromptTemplate(input_variables=['img'], template={'url': 'data:image/png;base64,{img}'}), PromptTemplate(input_variables=['bbox_descriptions'], template='{bbox_descriptions}'), PromptTemplate(input_variables=['input'], template='{input}')])]

# %%
llm = ChatOpenAI(model="gpt-4-turbo", max_tokens=4096)
agent = annotate | RunnablePassthrough.assign(
    prediction=format_descriptions | prompt2 | llm | StrOutputParser() | parse
)

# %%
import re


def update_scratchpad(state: AgentState):
    """After a tool is invoked, we want to update
    the scratchpad so the agent is aware of its previous steps"""
    old = state.get("scratchpad")
    if old:
        txt = old[0].content
        last_line = txt.rsplit("\n", 1)[-1]
        step = int(re.match(r"\d+", last_line).group()) + 1
    else:
        txt = "Previous action observations:\n"
        step = 1
    txt += f"\n{step}. {state['observation']}"

    return {**state, "scratchpad": [SystemMessage(content=txt)]}

# %%
from langchain_core.runnables import RunnableLambda

from langgraph.graph import END, StateGraph

graph_builder = StateGraph(AgentState)


graph_builder.add_node("agent", agent)
graph_builder.set_entry_point("agent")

graph_builder.add_node("update_scratchpad", update_scratchpad)
graph_builder.add_edge("update_scratchpad", "agent")

tools = {
    "Click": click,
    "Type": type_text,
    "Scroll": scroll,
    "Wait": wait,
    "GoBack": go_back,
    "Google": to_google,
    "OpenNewTab": open_new_tab,
    "SwitchToPreviousTab": switch_to_previous_tab
}


for node_name, tool in tools.items():
    graph_builder.add_node(
        node_name,
        # The lambda ensures the function's string output is mapped to the "observation"
        # key in the AgentState
        RunnableLambda(tool) | (lambda observation: {"observation": observation}),
    )
    # Always return to the agent (by means of the update-scratchpad node)
    graph_builder.add_edge(node_name, "update_scratchpad")


def select_tool(state: AgentState):
    # Any time the agent completes, this function
    # is called to route the output to a tool or
    # to the end user.
    action = state["prediction"]["action"]
    if action == "ANSWER":
        return END
    if action == "retry":
        return "agent"
    return action


graph_builder.add_conditional_edges("agent", select_tool)

graph = graph_builder.compile()

# %%
from IPython import display
from playwright.async_api import async_playwright

browser = await async_playwright().start()
# We will set headless=False so we can watch the agent navigate the web.
browser = await browser.chromium.launch(headless=False, args=None)
page = await browser.new_page()
_ = await page.goto("https://collectivai.atlassian.net/jira/software/projects/KAN/boards/1")


async def call_agent(question: str, page, max_steps: int = 150):
    event_stream = graph.astream(
        {
            "page": page,
            "input": question,
            "scratchpad": [],
        },
        {
            "recursion_limit": max_steps,
        },
    )
    final_answer = None
    steps = []
    async for event in event_stream:
        # We'll display an event stream here
        if "agent" not in event:
            continue
        pred = event["agent"].get("prediction") or {}
        action = pred.get("action")
        action_input = pred.get("args")
        display.clear_output(wait=False)
        steps.append(f"{len(steps) + 1}. {action}: {action_input}")
        print("\n".join(steps))
        display.display(display.Image(base64.b64decode(event["agent"]["img"])))
        if "ANSWER" in action:
            final_answer = action_input[0]
            break
    return final_answer

# %%
# res = await call_agent("""
#                     You job is to add a contact with name John and email john@doe.com on hubspot. Your primary way to navigate the CRM should be from the side nav which is collapsed into icons.
#                     If any tutorial guide pops up that offers to help you in the task, refuse / decline it and do it on your own. 
#                     """, page)
# print(f"Final response: {res}")

res = await call_agent("""
                    Delete all the issues. 
                    """, page)
print(f"Final response: {res}")
# Out:
# 1. Wait: None
# 2. Wait: None
# 3. Wait: None
# 4. Click: ['43']
# 5. Click: ['43']
# 6. Click: ['43']
# 7. Click: ['43']
# 8. Click: ['43']
# 9. Click: ['43']
# 10. Wait: None
# 11. Click: ['43']
# 12. Wait: None
# 13. Click: ['43']
# 14. Wait: None
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# Exception ignored in: <function BaseEventLoop.__del__ at 0x105f68a40>
# Traceback (most recent call last):
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 692, in __del__
#     if not self.is_closed():
#            ^^^^^^^^^^^^^^^^
#   File "/Users/namanjain/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/base_events.py", line 689, in is_closed
#     return self._closed
#            ^^^^^^^^^^^^
# AttributeError: '_UnixSelectorEventLoop' object has no attribute '_closed'
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[136], line 7
#       1 # res = await call_agent("""
#       2 #                     You job is to add a contact with name John and email john@doe.com on hubspot. Your primary way to navigate the CRM should be from the side nav which is collapsed into icons.
#       3 #                     If any tutorial guide pops up that offers to help you in the task, refuse / decline it and do it on your own.
#       4 #                     """, page)
#       5 # print(f"Final response: {res}")
# ----> 7 res = await call_agent("""
#       8                     Delete all the issues
#       9                     """, page)
#      10 print(f"Final response: {res}")
#
# Cell In[133], line 24, in call_agent(question, page, max_steps)
#      22 final_answer = None
#      23 steps = []
# ---> 24 async for event in event_stream:
#      25     # We'll display an event stream here
#      26     if "agent" not in event:
#      27         continue
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langgraph/pregel/__init__.py:1517, in Pregel.astream(self, input, config, stream_mode, output_keys, input_keys, interrupt_before, interrupt_after, debug)
#    1515 fut.add_done_callback(_mark_cancelled_as_seen)
#    1516 # wait for the future to finish, shielded from cancellation
# -> 1517 await asyncio.shield(fut)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langgraph/pregel/retry.py:120, in arun_with_retry(task, retry_policy, stream)
#     118         pass
#     119 else:
# --> 120     await task.proc.ainvoke(task.input, task.config)
#     121 # if successful, end
#     122 break
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:2543, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    2541             input = await step.ainvoke(input, config, **kwargs)
#    2542         else:
# -> 2543             input = await step.ainvoke(input, config)
#    2544 # finish the root run
#    2545 except BaseException as e:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py:497, in RunnableAssign.ainvoke(self, input, config, **kwargs)
#     491 async def ainvoke(
#     492     self,
#     493     input: Dict[str, Any],
#     494     config: Optional[RunnableConfig] = None,
#     495     **kwargs: Any,
#     496 ) -> Dict[str, Any]:
# --> 497     return await self._acall_with_config(self._ainvoke, input, config, **kwargs)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:1649, in Runnable._acall_with_config(self, func, input, config, run_type, **kwargs)
#    1645 coro = acall_func_with_variable_args(
#    1646     func, input, config, run_manager, **kwargs
#    1647 )
#    1648 if accepts_context(asyncio.create_task):
# -> 1649     output: Output = await asyncio.create_task(coro, context=context)  # type: ignore
#    1650 else:
#    1651     output = await coro
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/runnables/passthrough.py:484, in RunnableAssign._ainvoke(self, input, run_manager, config, **kwargs)
#     471 async def _ainvoke(
#     472     self,
#     473     input: Dict[str, Any],
#    (...)
#     476     **kwargs: Any,
#     477 ) -> Dict[str, Any]:
#     478     assert isinstance(
#     479         input, dict
#     480     ), "The input to RunnablePassthrough.assign() must be a dict."
#     482     return {
#     483         **input,
# --> 484         **await self.mapper.ainvoke(
#     485             input,
#     486             patch_config(config, callbacks=run_manager.get_child()),
#     487             **kwargs,
#     488         ),
#     489     }
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:3180, in RunnableParallel.ainvoke(self, input, config, **kwargs)
#    3177 try:
#    3178     # copy to avoid issues from the caller mutating the steps during invoke()
#    3179     steps = dict(self.steps__)
# -> 3180     results = await asyncio.gather(
#    3181         *(
#    3182             step.ainvoke(
#    3183                 input,
#    3184                 # mark each step as a child run
#    3185                 patch_config(
#    3186                     config, callbacks=run_manager.get_child(f"map:key:{key}")
#    3187                 ),
#    3188             )
#    3189             for key, step in steps.items()
#    3190         )
#    3191     )
#    3192     output = {key: value for key, value in zip(steps, results)}
#    3193 # finish the root run
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/runnables/base.py:2543, in RunnableSequence.ainvoke(self, input, config, **kwargs)
#    2541             input = await step.ainvoke(input, config, **kwargs)
#    2542         else:
# -> 2543             input = await step.ainvoke(input, config)
#    2544 # finish the root run
#    2545 except BaseException as e:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:269, in BaseChatModel.ainvoke(self, input, config, stop, **kwargs)
#     260 async def ainvoke(
#     261     self,
#     262     input: LanguageModelInput,
#    (...)
#     266     **kwargs: Any,
#     267 ) -> BaseMessage:
#     268     config = ensure_config(config)
# --> 269     llm_result = await self.agenerate_prompt(
#     270         [self._convert_input(input)],
#     271         stop=stop,
#     272         callbacks=config.get("callbacks"),
#     273         tags=config.get("tags"),
#     274         metadata=config.get("metadata"),
#     275         run_name=config.get("run_name"),
#     276         run_id=config.pop("run_id", None),
#     277         **kwargs,
#     278     )
#     279     return cast(ChatGeneration, llm_result.generations[0][0]).message
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     683 async def agenerate_prompt(
#     684     self,
#     685     prompts: List[PromptValue],
#    (...)
#     688     **kwargs: Any,
#     689 ) -> LLMResult:
#     690     prompt_messages = [p.to_messages() for p in prompts]
# --> 691     return await self.agenerate(
#     692         prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     693     )
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:617, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     597 callback_manager = AsyncCallbackManager.configure(
#     598     callbacks,
#     599     self.callbacks,
#    (...)
#     604     self.metadata,
#     605 )
#     607 run_managers = await callback_manager.on_chat_model_start(
#     608     dumpd(self),
#     609     messages,
#    (...)
#     614     run_id=run_id,
#     615 )
# --> 617 results = await asyncio.gather(
#     618     *[
#     619         self._agenerate_with_cache(
#     620             m,
#     621             stop=stop,
#     622             run_manager=run_managers[i] if run_managers else None,
#     623             **kwargs,
#     624         )
#     625         for i, m in enumerate(messages)
#     626     ],
#     627     return_exceptions=True,
#     628 )
#     629 exceptions = []
#     630 for i, res in enumerate(results):
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:277, in Task.__step(***failed resolving arguments***)
#     273 try:
#     274     if exc is None:
#     275         # We use the `send` method directly, because coroutines
#     276         # don't have `__iter__` and `__next__` methods.
# --> 277         result = coro.send(None)
#     278     else:
#     279         result = coro.throw(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:836, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#     834 else:
#     835     if inspect.signature(self._agenerate).parameters.get("run_manager"):
# --> 836         result = await self._agenerate(
#     837             messages, stop=stop, run_manager=run_manager, **kwargs
#     838         )
#     839     else:
#     840         result = await self._agenerate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/langchain_openai/chat_models/base.py:674, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#     672     return await agenerate_from_stream(stream_iter)
#     673 payload = self._get_request_payload(messages, stop=stop, **kwargs)
# --> 674 response = await self.async_client.create(**payload)
#     675 return self._create_chat_result(response)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/openai/resources/chat/completions.py:1289, in AsyncCompletions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1255 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1256 async def create(
#    1257     self,
#    (...)
#    1287     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1288 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
# -> 1289     return await self._post(
#    1290         "/chat/completions",
#    1291         body=await async_maybe_transform(
#    1292             {
#    1293                 "messages": messages,
#    1294                 "model": model,
#    1295                 "frequency_penalty": frequency_penalty,
#    1296                 "function_call": function_call,
#    1297                 "functions": functions,
#    1298                 "logit_bias": logit_bias,
#    1299                 "logprobs": logprobs,
#    1300                 "max_tokens": max_tokens,
#    1301                 "n": n,
#    1302                 "parallel_tool_calls": parallel_tool_calls,
#    1303                 "presence_penalty": presence_penalty,
#    1304                 "response_format": response_format,
#    1305                 "seed": seed,
#    1306                 "service_tier": service_tier,
#    1307                 "stop": stop,
#    1308                 "stream": stream,
#    1309                 "stream_options": stream_options,
#    1310                 "temperature": temperature,
#    1311                 "tool_choice": tool_choice,
#    1312                 "tools": tools,
#    1313                 "top_logprobs": top_logprobs,
#    1314                 "top_p": top_p,
#    1315                 "user": user,
#    1316             },
#    1317             completion_create_params.CompletionCreateParams,
#    1318         ),
#    1319         options=make_request_options(
#    1320             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1321         ),
#    1322         cast_to=ChatCompletion,
#    1323         stream=stream or False,
#    1324         stream_cls=AsyncStream[ChatCompletionChunk],
#    1325     )
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/openai/_base_client.py:1816, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1802 async def post(
#    1803     self,
#    1804     path: str,
#    (...)
#    1811     stream_cls: type[_AsyncStreamT] | None = None,
#    1812 ) -> ResponseT | _AsyncStreamT:
#    1813     opts = FinalRequestOptions.construct(
#    1814         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1815     )
# -> 1816     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/openai/_base_client.py:1514, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1505 async def request(
#    1506     self,
#    1507     cast_to: Type[ResponseT],
#    (...)
#    1512     remaining_retries: Optional[int] = None,
#    1513 ) -> ResponseT | _AsyncStreamT:
# -> 1514     return await self._request(
#    1515         cast_to=cast_to,
#    1516         options=options,
#    1517         stream=stream,
#    1518         stream_cls=stream_cls,
#    1519         remaining_retries=remaining_retries,
#    1520     )
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/openai/_base_client.py:1548, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1545     kwargs["auth"] = self.custom_auth
#    1547 try:
# -> 1548     response = await self._client.send(
#    1549         request,
#    1550         stream=stream or self._should_stream_response_body(request=request),
#    1551         **kwargs,
#    1552     )
#    1553 except httpx.TimeoutException as err:
#    1554     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpx/_client.py:1661, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1653 follow_redirects = (
#    1654     self.follow_redirects
#    1655     if isinstance(follow_redirects, UseClientDefault)
#    1656     else follow_redirects
#    1657 )
#    1659 auth = self._build_request_auth(request, auth)
# -> 1661 response = await self._send_handling_auth(
#    1662     request,
#    1663     auth=auth,
#    1664     follow_redirects=follow_redirects,
#    1665     history=[],
#    1666 )
#    1667 try:
#    1668     if not stream:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpx/_client.py:1689, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1686 request = await auth_flow.__anext__()
#    1688 while True:
# -> 1689     response = await self._send_handling_redirects(
#    1690         request,
#    1691         follow_redirects=follow_redirects,
#    1692         history=history,
#    1693     )
#    1694     try:
#    1695         try:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpx/_client.py:1726, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1723 for hook in self._event_hooks["request"]:
#    1724     await hook(request)
# -> 1726 response = await self._send_single_request(request)
#    1727 try:
#    1728     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpx/_client.py:1763, in AsyncClient._send_single_request(self, request)
#    1758     raise RuntimeError(
#    1759         "Attempted to send an sync request with an AsyncClient instance."
#    1760     )
#    1762 with request_context(request=request):
# -> 1763     response = await transport.handle_async_request(request)
#    1765 assert isinstance(response.stream, AsyncByteStream)
#    1766 response.request = request
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpx/_transports/default.py:373, in AsyncHTTPTransport.handle_async_request(self, request)
#     360 req = httpcore.Request(
#     361     method=request.method,
#     362     url=httpcore.URL(
#    (...)
#     370     extensions=request.extensions,
#     371 )
#     372 with map_httpcore_exceptions():
# --> 373     resp = await self._pool.handle_async_request(req)
#     375 assert isinstance(resp.stream, typing.AsyncIterable)
#     377 return Response(
#     378     status_code=resp.status,
#     379     headers=resp.headers,
#     380     stream=AsyncResponseStream(resp.stream),
#     381     extensions=resp.extensions,
#     382 )
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:216, in AsyncConnectionPool.handle_async_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     await self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, AsyncIterable)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:196, in AsyncConnectionPool.handle_async_request(self, request)
#     192 connection = await pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = await connection.handle_async_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/connection.py:101, in AsyncHTTPConnection.handle_async_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return await self._connection.handle_async_request(request)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/http11.py:143, in AsyncHTTP11Connection.handle_async_request(self, request)
#     141     async with Trace("response_closed", logger, request) as trace:
#     142         await self._response_closed()
# --> 143 raise exc
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/http11.py:113, in AsyncHTTP11Connection.handle_async_request(self, request)
#     102     pass
#     104 async with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = await self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/http11.py:186, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = await self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_async/http11.py:224, in AsyncHTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = await self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/httpcore/_backends/anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/anyio/streams/tls.py:205, in TLSStream.receive(self, max_bytes)
#     204 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 205     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     206     if not data:
#     207         raise EndOfStream
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/anyio/streams/tls.py:147, in TLSStream._call_sslobject_method(self, func, *args)
#     144     if self._write_bio.pending:
#     145         await self.transport_stream.send(self._write_bio.read())
# --> 147     data = await self.transport_stream.receive()
#     148 except EndOfStream:
#     149     self._read_bio.write_eof()
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/site-packages/anyio/_backends/_asyncio.py:1142, in SocketStream.receive(self, max_bytes)
#    1136 if (
#    1137     not self._protocol.read_event.is_set()
#    1138     and not self._transport.is_closing()
#    1139     and not self._protocol.is_at_eof
#    1140 ):
#    1141     self._transport.resume_reading()
# -> 1142     await self._protocol.read_event.wait()
#    1143     self._transport.pause_reading()
#    1144 else:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/futures.py:287, in Future.__await__(self)
#     285 if not self.done():
#     286     self._asyncio_future_blocking = True
# --> 287     yield self  # This tells Task to wait for completion.
#     288 if not self.done():
#     289     raise RuntimeError("await wasn't used with future")
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/tasks.py:349, in Task.__wakeup(self, future)
#     347 def __wakeup(self, future):
#     348     try:
# --> 349         future.result()
#     350     except BaseException as exc:
#     351         # This may also be a cancellation.
#     352         self.__step(exc)
#
# File ~/Desktop/repos/supademo/.conda/lib/python3.11/asyncio/futures.py:198, in Future.result(self)
#     196 if self._state == _CANCELLED:
#     197     exc = self._make_cancelled_error()
# --> 198     raise exc
#     199 if self._state != _FINISHED:
#     200     raise exceptions.InvalidStateError('Result is not ready.')
#
# CancelledError:

# %%
page.evaluate("unmarkPage()")
# Out:
# <coroutine object Page.evaluate at 0x10f986740>

# %%
import json

async def test_mark_page_script(page):
        
        # Read the mark_page.js script
        with open("mark_page2.js", "r") as f:
            mark_page_script = f.read()
        
        # Inject and execute the script
        await page.evaluate(mark_page_script)
        
        # Execute markPage() and get the results
        result = await page.evaluate("markPage()")
        
        # Print the results
        print(json.dumps(result, indent=2))
        
        # Keep the browser open for 10 seconds to visually inspect the bounding boxes
        await page.wait_for_timeout(10000)


# Example usage
await test_mark_page_script(page)
# Out:
# [
#   [
#     {
#       "id": "element-0",
#       "interactable": false,
#       "tagName": "body",
#       "attributes": {
#         "class": "hubspot ui-app sticky-global-toolbar hubspot-disable-focus-styles",
#         "unique_id": "FdAx",
#         "style": "--global-nav-sticky-nav-before-container-top: 0px; --global-nav-sticky-growth-dynamic-container-top: 0px; --global-nav-notifications-banner-iframe-top: 0px; --global-nav-onboarding-tours-banner-top: 0px; --global-nav-sticky-nav-top: 0px;"
#       },
#       "text": "\u2318 K Upgrade       collectivai.com User Guides Marketing Guide Sales Guide Customer Service Guide Content Guide Commerce Guide View your plan Invite your team Start overview demo Your Sales tools progress 17% complete 17% Recommended: All you need to get started Set up the basics Import your contacts, invite teammates, and understand HubSpot properties 40% complete 40% About 8 minutes left Close more deals faster with Sales Hub Track your deals in one place Create a custom pipeline, and never lose track of a sale again 0% About 4 minutes Quickly connect with leads Send emails and schedule meetings, all from the contact record 0% About 7 minutes Close deals and analyze performance Forecast performance and hit your goals with a reports dashboard 0% About 2 minutes Learn more about sales tools Take a demo of your sales tools Get started with a 2 minute lesson on organizing your sales data in HubSpot Work from anywhere with the HubSpot Mobile App Connect sales apps from the App Marketplace",
#       "rect": {
#         "bottom": 720,
#         "top": 0,
#         "left": 0,
#         "right": 1280,
#         "width": 1280,
#         "height": 720
#       },
#       "children": [
#         {
#           "id": "hs-nav-v4",
#           "interactable": false,
#           "tagName": "div",
#           "attributes": {
#             "id": "hs-nav-v4",
#             "class": "nav-width-flex placeholder-nav",
#             "unique_id": "ptYR"
#           },
#           "text": "\u2318 K Upgrade       collectivai.com",
#           "rect": {
#             "bottom": 44,
#             "top": 0,
#             "left": 0,
#             "right": 1280,
#             "width": 1280,
#             "height": 44
#           },
#           "children": [
#             {
#               "id": "hs-global-toolbar-root",
#               "interactable": true,
#               "tagName": "div",
#               "attributes": {
#                 "id": "hs-global-toolbar-root",
#                 "unique_id": "bMhK"
#               },
#               "text": "\u2318 K Upgrade       collectivai.com",
#               "rect": {
#                 "bottom": 44,
#                 "top": 0,
#                 "left": 0,
#                 "right": 1280,
#                 "width": 1280,
#                 "height": 44
#               },
#               "children": [
#                 {
#                   "id": "hs-global-toolbar",
#                   "interactable": false,
#                   "tagName": "header",
#                   "attributes": {
#                     "id": "hs-global-toolbar",
#                     "data-test-id": "hs-global-toolbar",
#                     "class": "GlobalToolbar__StyledHeader-g9am2v-3 dABJHu",
#                     "unique_id": "Tm2N"
#                   },
#                   "text": "\u2318 K Upgrade       collectivai.com",
#                   "rect": {
#                     "bottom": 44,
#                     "top": 0,
#                     "left": 0,
#                     "right": 1280,
#                     "width": 1280,
#                     "height": 44
#                   },
#                   "children": [
#                     {
#                       "id": "element-4",
#                       "interactable": false,
#                       "tagName": "div",
#                       "attributes": {
#                         "class": "hs-toolbar-logo-container",
#                         "unique_id": "dYhx"
#                       },
#                       "text": "",
#                       "rect": {
#                         "bottom": 44,
#                         "top": 0,
#                         "left": 12,
#                         "right": 64,
#                         "width": 52,
#                         "height": 44
#                       },
#                       "children": [
#                         {
#                           "id": "nav-home-link",
#                           "interactable": true,
#                           "tagName": "a",
#                           "attributes": {
#                             "class": "GlobalToolbar__StyledLogoLink-g9am2v-4 locOFQ",
#                             "data-test-id": "home-link",
#                             "href": "/user-guide/46683262?via=home",
#                             "id": "nav-home-link",
#                             "unique_id": "nN0d"
#                           },
#                           "text": "",
#                           "rect": {
#                             "bottom": 40.5,
#                             "top": 3.5,
#                             "left": 12,
#                             "right": 53,
#                             "width": 41,
#                             "height": 37
#                           },
#                           "children": []
#                         }
#                       ]
#                     },
#                     {
#                       "id": "element-6",
#                       "interactable": false,
#                       "tagName": "div",
#                       "attributes": {
#                         "class": "GlobalToolbar__SearchSectionWrapper-g9am2v-0 krjwVP",
#                         "unique_id": "dROa"
#                       },
#                       "text": "\u2318 K",
#                       "rect": {
#                         "bottom": 44,
#                         "top": 0,
#                         "left": 64,
#                         "right": 749.5078125,
#                         "width": 685.5078125,
#                         "height": 44
#                       },
#                       "children": [
#                         {
#                           "id": "element-7",
#                           "interactable": false,
#                           "tagName": "div",
#                           "attributes": {
#                             "class": "GlobalToolbar__SearchInputWrapper-g9am2v-1 fRNvel",
#                             "unique_id": "HMso"
#                           },
#                           "text": "\u2318 K",
#                           "rect": {
#                             "bottom": 44,
#                             "top": 0,
#                             "left": 64,
#                             "right": 614,
#                             "width": 550,
#                             "height": 44
#                           },
#                           "children": [
#                             {
#                               "id": "element-8",
#                               "interactable": false,
#                               "tagName": "div",
#                               "attributes": {
#                                 "class": "StyledSearchWrapper-sc-12kwptg-0 ljqOyr",
#                                 "unique_id": "JMxH"
#                               },
#                               "text": "\u2318 K",
#                               "rect": {
#                                 "bottom": 44,
#                                 "top": 0,
#                                 "left": 64,
#                                 "right": 614,
#                                 "width": 550,
#                                 "height": 44
#                               },
#                               "children": [
#                                 {
#                                   "id": "hs-search-react",
#                                   "interactable": false,
#                                   "tagName": "form",
#                                   "attributes": {
#                                     "id": "hs-search-react",
#                                     "data-onboarding-hook": "search",
#                                     "class": "SearchForm-sc-161bglf-0 hbRWxz",
#                                     "unique_id": "mSVT"
#                                   },
#                                   "text": "\u2318 K",
#                                   "rect": {
#                                     "bottom": 38,
#                                     "top": 6,
#                                     "left": 64,
#                                     "right": 614,
#                                     "width": 550,
#                                     "height": 32
#                                   },
#                                   "children": [
#                                     {
#                                       "id": "element-10",
#                                       "interactable": false,
#                                       "tagName": "div",
#                                       "attributes": {
#                                         "class": "GlobalSearchInput__StyledFlexDiv-sc-3rzpxk-0 iZsuEe",
#                                         "unique_id": "4YTG"
#                                       },
#                                       "text": "\u2318 K",
#                                       "rect": {
#                                         "bottom": 38,
#                                         "top": 6,
#                                         "left": 64,
#                                         "right": 614,
#                                         "width": 550,
#                                         "height": 32
#                                       },
#                                       "children": [
#                                         {
#                                           "id": "element-11",
#                                           "interactable": true,
#                                           "tagName": "button",
#                                           "attributes": {
#                                             "type": "submit",
#                                             "class": "SearchButton-sc-101koaq-0 jWVojc",
#                                             "unique_id": "0F00"
#                                           },
#                                           "text": "",
#                                           "rect": {
#                                             "bottom": 38,
#                                             "top": 6,
#                                             "left": 64,
#                                             "right": 96,
#                                             "width": 32,
#                                             "height": 32
#                                           },
#                                           "children": []
#                                         },
#                                         {
#                                           "id": "global-search-input",
#                                           "interactable": true,
#                                           "tagName": "input",
#                                           "attributes": {
#                                             "id": "global-search-input",
#                                             "name": "global-search-input",
#                                             "type": "search",
#                                             "data-test-id": "global-search-input-react",
#                                             "aria-label": "Search HubSpot",
#                                             "autocomplete": "off",
#                                             "minlength": "1",
#                                             "maxlength": "512",
#                                             "placeholder": "Search HubSpot",
#                                             "class": "StyledSearchInput-sc-1ki1emt-0 myxKE",
#                                             "value": "",
#                                             "unique_id": "Rasx"
#                                           },
#                                           "text": "",
#                                           "rect": {
#                                             "bottom": 38,
#                                             "top": 6,
#                                             "left": 96,
#                                             "right": 550,
#                                             "width": 454,
#                                             "height": 32
#                                           },
#                                           "children": []
#                                         },
#                                         {
#                                           "id": "element-13",
#                                           "interactable": false,
#                                           "tagName": "label",
#                                           "attributes": {
#                                             "for": "global-search-input",
#                                             "class": "StyledShortcusHints-sc-19smeqd-0 khkQDx",
#                                             "unique_id": "UEkw"
#                                           },
#                                           "text": "\u2318 K",
#                                           "rect": {
#                                             "bottom": 38,
#                                             "top": 6,
#                                             "left": 550,
#                                             "right": 614,
#                                             "width": 64,
#                                             "height": 32
#                                           },
#                                           "children": [
#                                             {
#                                               "id": "element-14",
#                                               "interactable": false,
#                                               "tagName": "span",
#                                               "attributes": {
#                                                 "class": "StyledKey-gze0l0-0 gLtIRF",
#                                                 "unique_id": "VRad"
#                                               },
#                                               "text": "\u2318",
#                                               "rect": {
#                                                 "bottom": 30,
#                                                 "top": 14,
#                                                 "left": 554,
#                                                 "right": 574,
#                                                 "width": 20,
#                                                 "height": 16
#                                               },
#                                               "children": []
#                                             },
#                                             {
#                                               "id": "element-15",
#                                               "interactable": false,
#                                               "tagName": "span",
#                                               "attributes": {
#                                                 "class": "StyledKey-gze0l0-0 gLtIRF",
#                                                 "unique_id": "RXNc"
#                                               },
#                                               "text": "K",
#                                               "rect": {
#                                                 "bottom": 30,
#                                                 "top": 14,
#                                                 "left": 578,
#                                                 "right": 594,
#                                                 "width": 16,
#                                                 "height": 16
#                                               },
#                                               "children": []
#                                             }
#                                           ]
#                                         }
#                                       ]
#                                     }
#                                   ]
#                                 }
#                               ]
#                             }
#                           ]
#                         }
#                       ]
#                     },
#                     {
#                       "id": "element-16",
#                       "interactable": false,
#                       "tagName": "nav",
#                       "attributes": {
#                         "class": "global-toolbar-items-container",
#                         "aria-label": "Global toolbar",
#                         "unique_id": "PDq3"
#                       },
#                       "text": "Upgrade       collectivai.com",
#                       "rect": {
#                         "bottom": 44,
#                         "top": 0,
#                         "left": 749.5078125,
#                         "right": 1268,
#                         "width": 518.4921875,
#                         "height": 44
#                       },
#                       "children": [
#                         {
#                           "id": "hs-global-toolbar-icons",
#                           "interactable": false,
#                           "tagName": "ul",
#                           "attributes": {
#                             "id": "hs-global-toolbar-icons",
#                             "role": "menu",
#                             "aria-orientation": "horizontal",
#                             "data-test-id": "hs-global-toolbar-icons",
#                             "class": "hs-toolbar-list",
#                             "unique_id": "3w8q"
#                           },
#                           "text": "Upgrade       collectivai.com",
#                           "rect": {
#                             "bottom": 44,
#                             "top": 0,
#                             "left": 749.5078125,
#                             "right": 1268,
#                             "width": 518.4921875,
#                             "height": 44
#                           },
#                           "children": [
#                             {
#                               "id": "element-18",
#                               "interactable": false,
#                               "tagName": "li",
#                               "attributes": {
#                                 "role": "menuitem",
#                                 "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 eqwvKd",
#                                 "unique_id": "L0aW"
#                               },
#                               "text": "Upgrade",
#                               "rect": {
#                                 "bottom": 38,
#                                 "top": 6,
#                                 "left": 754.5078125,
#                                 "right": 871.484375,
#                                 "width": 116.9765625,
#                                 "height": 32
#                               },
#                               "children": [
#                                 {
#                                   "id": "hs-global-toolbar-suite-starter-list-item",
#                                   "interactable": true,
#                                   "tagName": "a",
#                                   "attributes": {
#                                     "class": "GlobalToolbarLink__StyledLink-sc-7orc6n-0 igcCPY",
#                                     "id": "hs-global-toolbar-suite-starter-list-item",
#                                     "data-test-id": "hs-global-toolbar-suite-starter-list-item",
#                                     "href": "https://app.hubspot.com/pricing/46683262/upgrade?upgradeSource=global-nav-bar",
#                                     "aria-label": "Upgrade",
#                                     "unique_id": "bdXS"
#                                   },
#                                   "text": "Upgrade",
#                                   "rect": {
#                                     "bottom": 38,
#                                     "top": 6,
#                                     "left": 754.5078125,
#                                     "right": 848.484375,
#                                     "width": 93.9765625,
#                                     "height": 32
#                                   },
#                                   "children": [
#                                     {
#                                       "id": "element-20",
#                                       "interactable": true,
#                                       "tagName": "span",
#                                       "attributes": {
#                                         "class": "icon-text-key",
#                                         "unique_id": "IghN"
#                                       },
#                                       "text": "Upgrade",
#                                       "rect": {
#                                         "bottom": 34,
#                                         "top": 10,
#                                         "left": 778.5078125,
#                                         "right": 840.484375,
#                                         "width": 61.9765625,
#                                         "height": 24
#                                       },
#                                       "children": []
#                                     }
#                                   ]
#                                 }
#                               ]
#                             },
#                             {
#                               "id": "element-21",
#                               "interactable": false,
#                               "tagName": "li",
#                               "attributes": {
#                                 "role": "menuitem",
#                                 "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 cdaiTj",
#                                 "unique_id": "fDKs"
#                               },
#                               "text": "",
#                               "rect": {
#                                 "bottom": 37,
#                                 "top": 7,
#                                 "left": 881.484375,
#                                 "right": 911.484375,
#                                 "width": 30,
#                                 "height": 30
#                               },
#                               "children": [
#                                 {
#                                   "id": "element-22",
#                                   "interactable": false,
#                                   "tagName": "div",
#                                   "attributes": {
#                                     "data-portal-hook": "calling-remote",
#                                     "aria-haspopup": "menu",
#                                     "aria-expanded": "false",
#                                     "unique_id": "HhOf"
#                                   },
#                                   "text": "",
#                                   "rect": {
#                                     "bottom": 37,
#                                     "top": 7,
#                                     "left": 881.484375,
#                                     "right": 911.484375,
#                                     "width": 30,
#                                     "height": 30
#                                   },
#                                   "children": [
#                                     {
#                                       "id": "element-23",
#                                       "interactable": true,
#                                       "tagName": "button",
#                                       "attributes": {
#                                         "aria-label": "call dropdown",
#                                         "data-selenium-test": "call-remote-toggle",
#                                         "class": "Callstyles__NewStyledToggleButton-sc-1ajwq6k-0 hokRYm",
#                                         "unique_id": "oKmb"
#                                       },
#                                       "text": "",
#                                       "rect": {
#                                         "bottom": 37,
#                                         "top": 7,
#                                         "left": 881.484375,
#                                         "right": 911.484375,
#                                         "width": 30,
#                                         "height": 30
#                                       },
#                                       "children": [
#                                         {
#                                           "id": "element-24",
#                                           "interactable": true,
#                                           "tagName": "div",
#                                           "attributes": {
#                                             "data-onboarding": "calling-remote",
#                                             "unique_id": "62QY",
#                                             "style": "position: relative; line-height: normal; display: flex;"
#                                           },
#                                           "text": "",
#                                           "rect": {
#                                             "bottom": 29,
#                                             "top": 15,
#                                             "left": 889.484375,
#                                             "right": 903.484375,
#                                             "width": 14,
#                                             "height": 14
#                                           },
#                                           "children": []
#                                         }
#                                       ]
#                                     }
#                                   ]
#                                 }
#                               ]
#                             },
#                             {
#                               "id": "element-25",
#                               "interactable": false,
#                               "tagName": "li",
#                               "attributes": {
#                                 "data-portal-hook": "marketplace-menu",
#                                 "role": "menuitem",
#                                 "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 gFuatf",
#                                 "unique_id": "aoV0"
#                               },
#                               "text": "",
#                               "rect": {
#                                 "bottom": 38,
#                                 "top": 6,
#                                 "left": 921.484375,
#                                 "right": 953.484375,
#                                 "width": 32,
#                                 "height": 32
#                               },
#                               "children": [
#                                 {
#                                   "id": "hs-global-toolbar-marketplace-list-item",
#                                   "interactable": true,
#                                   "tagName": "button",
#                                   "attributes": {
#                                     "class": "Marketplace__StyledMenuButton-sc-6d3dsf-0 cQeNEB",
#                                     "id": "hs-global-toolbar-marketplace-list-item",
#                                     "aria-haspopup": "true",
#                                     "data-test-id": "hs-global-toolbar-marketplace-list-item",
#                                     "aria-label": "Marketplaces",
#                                     "unique_id": "5YNS"
#                                   },
#                                   "text": "",
#                                   "rect": {
#                                     "bottom": 38,
#                                     "top": 6,
#                                     "left": 921.484375,
#                                     "right": 953.484375,
#                                     "width": 32,
#                                     "height": 32
#                                   },
#                                   "children": []
#                                 }
#                               ]
#                             },
#                             {
#                               "id": "element-27",
#                               "interactable": false,
#                               "tagName": "li",
#                               "attributes": {
#                                 "role": "menuitem",
#                                 "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 cdaiTj",
#                                 "unique_id": "UCjc"
#                               },
#                               "text": "",
#                               "rect": {
#                                 "bottom": 38,
#                                 "top": 6,
#                                 "left": 963.484375,
#                                 "right": 995.484375,
#                                 "width": 32,
#                                 "height": 32
#                               },
#                               "children": [
#                                 {
#                                   "id": "element-28",
#                                   "interactable": false,
#                                   "tagName": "div",
#                                   "attributes": {
#                                     "class": "GlobalToolbarTooltip__StyledDiv-sc-1jrrqmw-0 jMoBDL",
#                                     "unique_id": "F11T"
#                                   },
#                                   "text": "",
#                                   "rect": {
#                                     "bottom": 38,
#                                     "top": 6,
#                                     "left": 963.484375,
#                                     "right": 995.484375,
#                                     "width": 32,
#                                     "height": 32
#                                   },
#                                   "children": [
#                                     {
#                                       "id": "hs-global-toolbar-help-list-item",
#                                       "interactable": true,
#                                       "tagName": "button",
#                                       "attributes": {
#                                         "class": "Help__StyledHelpButton-adn6uf-0 eINRoS",
#                                         "aria-label": "Help",
#                                         "aria-haspopup": "dialog",
#                                         "aria-owns": "help-widget",
#                                         "aria-expanded": "false",
#                                         "data-test-id": "hs-global-toolbar-help-list-item",
#                                         "id": "hs-global-toolbar-help-list-item",
#                                         "unique_id": "HnRo"
#                                       },
#                                       "text": "",
#                                       "rect": {
#                                         "bottom": 38,
#                                         "top": 6,
#                                         "left": 963.484375,
#                                         "right": 995.484375,
#                                         "width": 32,
#                                         "height": 32
#                                       },
#                                       "children": []
#                                     }
#                                   ]
#                                 }
#                               ]
#                             },
#                             {
#                               "id": "element-30",
#                               "interactable": false,
#                               "tagName": "li",
#                               "attributes": {
#                                 "role": "menuitem",
#                                 "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 gFuatf",
#                                 "unique_id": "eQw1"
#                               },
#                               "text": "",
#                               "rect": {
#                                 "bottom": 38,
#                                 "top": 6,
#                                 "left": 1005.484375,
#                                 "right": 1037.484375,
#                                 "width": 32,
#                                 "height": 32
#                               },
#                               "children": [
#                                 {
#                                   "id": "hs-global-toolbar-settings-list-item",
#                                   "interactable": true,
#                                   "tagName": "a",
#                                   "attributes": {
#                                     "class": "GlobalToolbarLink__StyledLink-sc-7orc6n-0 iBcQeC",
#                                     "id": "hs-global-toolbar-settings-list-item",
#                                     "data-test-id": "hs-global-toolbar-settings-list-item",
#                                     "href": "/user-preferences/46683262?eschref=%2Fuser-guide%2F46683262",
#                                     "aria-label": "Settings",
#                                     "unique_id": "1Sdk"
#                                   },
#                                   "text": "",
#                                   "rect": {
#                                     "bottom": 38,
#                                     "top": 6,
#                                     "left": 1005.484375,
#                                     "right": 1037.484375,
#                                     "width": 32,
#                                     "height": 32
#                                   },
#                                   "children": []
#                                 }
#                               ]
#                             },
#                             {
#                               "id": "element-32",
#                               "interactable": false,
#                               "tagName": "div",
#                               "attributes": {
#                                 "class": "UnseenIndicator__Container-sc-1ulep2q-0 eWNBmw",
#                                 "unique_id": "db7b"
#                               },
#                               "text": "",
#                               "rect": {
#                                 "bottom": 44,
#                                 "top": 0,
#                                 "left": 1042.484375,
#                                 "right": 1084.484375,
#                                 "width": 42,
#                                 "height": 44
#                               },
#                               "children": [
#                                 {
#                                   "id": "element-33",
#                                   "interactable": true,
#                                   "tagName": "li",
#                                   "attributes": {
#                                     "role": "menuitem",
#                                     "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 cdaiTj",
#                                     "unique_id": "PtaO"
#                                   },
#                                   "text": "",
#                                   "rect": {
#                                     "bottom": 44,
#                                     "top": 0,
#                                     "left": 1047.484375,
#                                     "right": 1079.484375,
#                                     "width": 32,
#                                     "height": 44
#                                   },
#                                   "children": [
#                                     {
#                                       "id": "hs-global-toolbar-notifications-list-item",
#                                       "interactable": true,
#                                       "tagName": "button",
#                                       "attributes": {
#                                         "class": "GlobalToolbarButton__StyledButton-sc-41qur4-0 iZYGoF",
#                                         "id": "hs-global-toolbar-notifications-list-item",
#                                         "data-test-id": "hs-global-toolbar-notifications-list-item",
#                                         "aria-expanded": "false",
#                                         "aria-label": "Notifications",
#                                         "unique_id": "wfzw"
#                                       },
#                                       "text": "",
#                                       "rect": {
#                                         "bottom": 38,
#                                         "top": 6,
#                                         "left": 1047.484375,
#                                         "right": 1079.484375,
#                                         "width": 32,
#                                         "height": 32
#                                       },
#                                       "children": []
#                                     }
#                                   ]
#                                 }
#                               ]
#                             },
#                             {
#                               "id": "element-35",
#                               "interactable": false,
#                               "tagName": "li",
#                               "attributes": {
#                                 "data-portal-hook": "account-menu",
#                                 "data-onboarding-hook": "opt-out",
#                                 "role": "menuitem",
#                                 "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 fdKxzG",
#                                 "unique_id": "4eHb"
#                               },
#                               "text": "collectivai.com",
#                               "rect": {
#                                 "bottom": 38,
#                                 "top": 6,
#                                 "left": 1112.484375,
#                                 "right": 1268,
#                                 "width": 155.515625,
#                                 "height": 32
#                               },
#                               "children": [
#                                 {
#                                   "id": "hs-global-toolbar-accounts",
#                                   "interactable": true,
#                                   "tagName": "button",
#                                   "attributes": {
#                                     "class": "Accounts__StyledMenuButton-pw7djs-0 fZvaPC",
#                                     "id": "hs-global-toolbar-accounts",
#                                     "aria-haspopup": "true",
#                                     "data-test-id": "hs-global-toolbar-accounts",
#                                     "unique_id": "N9qX"
#                                   },
#                                   "text": "collectivai.com",
#                                   "rect": {
#                                     "bottom": 38,
#                                     "top": 6,
#                                     "left": 1112.484375,
#                                     "right": 1268,
#                                     "width": 155.515625,
#                                     "height": 32
#                                   },
#                                   "children": [
#                                     {
#                                       "id": "element-37",
#                                       "interactable": true,
#                                       "tagName": "img",
#                                       "attributes": {
#                                         "src": "https://api-na1.hubspot.com/userpreferences/v1/avatar/b9364a66a8142788411895c9b0cc8d3e/100",
#                                         "alt": "Nischal Jain",
#                                         "unique_id": "5ovh"
#                                       },
#                                       "text": "",
#                                       "rect": {
#                                         "bottom": 30,
#                                         "top": 14,
#                                         "left": 1120.484375,
#                                         "right": 1136.484375,
#                                         "width": 16,
#                                         "height": 16
#                                       },
#                                       "children": []
#                                     },
#                                     {
#                                       "id": "element-38",
#                                       "interactable": true,
#                                       "tagName": "span",
#                                       "attributes": {
#                                         "unique_id": "pnLj"
#                                       },
#                                       "text": "collectivai.com",
#                                       "rect": {
#                                         "bottom": 31,
#                                         "top": 13,
#                                         "left": 1144.484375,
#                                         "right": 1242,
#                                         "width": 97.515625,
#                                         "height": 18
#                                       },
#                                       "children": []
#                                     }
#                                   ]
#                                 }
#                               ]
#                             }
#                           ]
#                         }
#                       ]
#                     }
#                   ]
#                 }
#               ]
#             }
#           ]
#         },
#         {
#           "id": "element-39",
#           "interactable": false,
#           "tagName": "div",
#           "attributes": {
#             "class": "page copilot-grid-layout with-copilot-sidebar",
#             "unique_id": "oXIk",
#             "style": "width: calc(100% - var(--global-nav-vertical-nav-width, 236px)); margin-left: auto;"
#           },
#           "text": "User Guides Marketing Guide Sales Guide Customer Service Guide Content Guide Commerce Guide View your plan Invite your team Start overview demo Your Sales tools progress 17% complete 17% Recommended: All you need to get started Set up the basics Import your contacts, invite teammates, and understand HubSpot properties 40% complete 40% About 8 minutes left Close more deals faster with Sales Hub Track your deals in one place Create a custom pipeline, and never lose track of a sale again 0% About 4 minutes Quickly connect with leads Send emails and schedule meetings, all from the contact record 0% About 7 minutes Close deals and analyze performance Forecast performance and hit your goals with a reports dashboard 0% About 2 minutes Learn more about sales tools Take a demo of your sales tools Get started with a 2 minute lesson on organizing your sales data in HubSpot Work from anywhere with the HubSpot Mobile App Connect sales apps from the App Marketplace",
#           "rect": {
#             "bottom": 720,
#             "top": 44,
#             "left": 64,
#             "right": 1280,
#             "width": 1216,
#             "height": 676
#           },
#           "children": [
#             {
#               "id": "element-40",
#               "interactable": false,
#               "tagName": "div",
#               "attributes": {
#                 "class": "copilot-app-container",
#                 "unique_id": "GHXX"
#               },
#               "text": "User Guides Marketing Guide Sales Guide Customer Service Guide Content Guide Commerce Guide View your plan Invite your team Start overview demo Your Sales tools progress 17% complete 17% Recommended: All you need to get started Set up the basics Import your contacts, invite teammates, and understand HubSpot properties 40% complete 40% About 8 minutes left Close more deals faster with Sales Hub Track your deals in one place Create a custom pipeline, and never lose track of a sale again 0% About 4 minutes Quickly connect with leads Send emails and schedule meetings, all from the contact record 0% About 7 minutes Close deals and analyze performance Forecast performance and hit your goals with a reports dashboard 0% About 2 minutes Learn more about sales tools Take a demo of your sales tools Get started with a 2 minute lesson on organizing your sales data in HubSpot Work from anywhere with the HubSpot Mobile App Connect sales apps from the App Marketplace",
#               "rect": {
#                 "bottom": 720,
#                 "top": 44,
#                 "left": 64,
#                 "right": 1280,
#                 "width": 1216,
#                 "height": 676
#               },
#               "children": [
#                 {
#                   "id": "element-41",
#                   "interactable": false,
#                   "tagName": "div",
#                   "attributes": {
#                     "data-application-name": "setup-guide-ui",
#                     "unique_id": "RnoX"
#                   },
#                   "text": "User Guides Marketing Guide Sales Guide Customer Service Guide Content Guide Commerce Guide View your plan Invite your team Start overview demo Your Sales tools progress 17% complete 17% Recommended: All you need to get started Set up the basics Import your contacts, invite teammates, and understand HubSpot properties 40% complete 40% About 8 minutes left Close more deals faster with Sales Hub Track your deals in one place Create a custom pipeline, and never lose track of a sale again 0% About 4 minutes Quickly connect with leads Send emails and schedule meetings, all from the contact record 0% About 7 minutes Close deals and analyze performance Forecast performance and hit your goals with a reports dashboard 0% About 2 minutes Learn more about sales tools Take a demo of your sales tools Get started with a 2 minute lesson on organizing your sales data in HubSpot Work from anywhere with the HubSpot Mobile App Connect sales apps from the App Marketplace",
#                   "rect": {
#                     "bottom": 720,
#                     "top": 44,
#                     "left": 64,
#                     "right": 1280,
#                     "width": 1216,
#                     "height": 676
#                   },
#                   "children": [
#                     {
#                       "id": "element-42",
#                       "interactable": false,
#                       "tagName": "div",
#                       "attributes": {
#                         "direction": "row",
#                         "wrap": "nowrap",
#                         "class": "UIFlex__StyledFlex-sc-170bmag-0 ishYHb private-flex SetupGuideLayout__SetupGuideNavLayout-hatnox-0 iCWRpS",
#                         "unique_id": "DBlL"
#                       },
# ...
#       },
#       "text": "",
#       "rect": {
#         "bottom": 653,
#         "top": 637,
#         "left": 146,
#         "right": 162,
#         "width": 16,
#         "height": 16
#       },
#       "children": []
#     },
#     {
#       "id": "element-82",
#       "interactable": true,
#       "tagName": "span",
#       "attributes": {
#         "class": "UINavItemLabel__NavItemLabel-lgq02b-0 HRrqd UINavListItem__NavItemLabel-sc-1wsoe89-3 ioExzj",
#         "unique_id": "GP37"
#       },
#       "text": "Invite your team",
#       "rect": {
#         "bottom": 656,
#         "top": 632,
#         "left": 170,
#         "right": 305,
#         "width": 135,
#         "height": 24
#       },
#       "children": [
#         {
#           "id": "element-83",
#           "interactable": true,
#           "tagName": "i18n-string",
#           "attributes": {
#             "data-locale-at-render": "en-in",
#             "data-key": "app.tabs.inviteLink.text",
#             "unique_id": "FRWu"
#           },
#           "text": "Invite your team",
#           "rect": {
#             "bottom": 656,
#             "top": 632,
#             "left": 170,
#             "right": 280.1171875,
#             "width": 110.1171875,
#             "height": 24
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-83",
#       "interactable": true,
#       "tagName": "i18n-string",
#       "attributes": {
#         "data-locale-at-render": "en-in",
#         "data-key": "app.tabs.inviteLink.text",
#         "unique_id": "FRWu"
#       },
#       "text": "Invite your team",
#       "rect": {
#         "bottom": 656,
#         "top": 632,
#         "left": 170,
#         "right": 280.1171875,
#         "width": 110.1171875,
#         "height": 24
#       },
#       "children": []
#     },
#     {
#       "id": "element-84",
#       "interactable": true,
#       "tagName": "span",
#       "attributes": {
#         "class": "private-help-icon",
#         "unique_id": "FCwq",
#         "style": "padding-top: 2px;"
#       },
#       "text": "",
#       "rect": {
#         "bottom": 657,
#         "top": 631,
#         "left": 305,
#         "right": 326,
#         "width": 21,
#         "height": 26
#       },
#       "children": [
#         {
#           "id": "element-85",
#           "interactable": false,
#           "tagName": "span",
#           "attributes": {
#             "tabindex": "0",
#             "class": "private-icon private-icon__low private-help-icon__icon",
#             "data-icon-name": "info",
#             "unique_id": "5QF3",
#             "style": "color: rgb(124, 152, 182);"
#           },
#           "text": "",
#           "rect": {
#             "bottom": 657,
#             "top": 633,
#             "left": 312,
#             "right": 326,
#             "width": 14,
#             "height": 24
#           },
#           "children": [
#             {
#               "id": "element-86",
#               "interactable": false,
#               "tagName": "span",
#               "attributes": {
#                 "aria-hidden": "true",
#                 "class": "UIIcon__IconContent-sc-7c34id-0 bXLRwu",
#                 "unique_id": "jWzH"
#               },
#               "text": "",
#               "rect": {
#                 "bottom": 652,
#                 "top": 638,
#                 "left": 312,
#                 "right": 326,
#                 "width": 14,
#                 "height": 14
#               },
#               "children": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "element-88",
#       "interactable": true,
#       "tagName": "a",
#       "attributes": {
#         "data-test-id": "overview-demo",
#         "class": "private-link uiLinkWithoutUnderline UINavListItem__StyledLink-sc-1wsoe89-1 fxyTbj SetupGuideNavItem-sc-10oivvw-0 chrnQr private-nav-item uiLinkDark",
#         "href": "/crm-free-demo/46683262/free-crm",
#         "tabindex": "0",
#         "aria-disabled": "false",
#         "unique_id": "Ssur"
#       },
#       "text": "Start overview demo",
#       "rect": {
#         "bottom": 704,
#         "top": 664,
#         "left": 134,
#         "right": 338,
#         "width": 204,
#         "height": 40
#       },
#       "children": [
#         {
#           "id": "element-89",
#           "interactable": true,
#           "tagName": "span",
#           "attributes": {
#             "class": "private-icon private-icon__low",
#             "data-icon-name": "video",
#             "unique_id": "x02x",
#             "style": "color: rgb(51, 71, 91); padding-top: 2px; font-size: 16px;"
#           },
#           "text": "",
#           "rect": {
#             "bottom": 697,
#             "top": 671,
#             "left": 146,
#             "right": 162,
#             "width": 16,
#             "height": 26
#           },
#           "children": [
#             {
#               "id": "element-90",
#               "interactable": true,
#               "tagName": "span",
#               "attributes": {
#                 "aria-hidden": "true",
#                 "class": "UIIcon__IconContent-sc-7c34id-0 idUWwR",
#                 "unique_id": "RY9b"
#               },
#               "text": "",
#               "rect": {
#                 "bottom": 693,
#                 "top": 677,
#                 "left": 146,
#                 "right": 162,
#                 "width": 16,
#                 "height": 16
#               },
#               "children": []
#             }
#           ]
#         },
#         {
#           "id": "element-91",
#           "interactable": true,
#           "tagName": "span",
#           "attributes": {
#             "class": "UINavItemLabel__NavItemLabel-lgq02b-0 HRrqd UINavListItem__NavItemLabel-sc-1wsoe89-3 ioExzj",
#             "unique_id": "Q84k"
#           },
#           "text": "Start overview demo",
#           "rect": {
#             "bottom": 696,
#             "top": 672,
#             "left": 170,
#             "right": 326,
#             "width": 156,
#             "height": 24
#           },
#           "children": [
#             {
#               "id": "element-92",
#               "interactable": true,
#               "tagName": "i18n-string",
#               "attributes": {
#                 "data-locale-at-render": "en-in",
#                 "data-key": "app.tabs.startOverviewDemo",
#                 "unique_id": "whEG"
#               },
#               "text": "Start overview demo",
#               "rect": {
#                 "bottom": 696,
#                 "top": 672,
#                 "left": 170,
#                 "right": 307.75,
#                 "width": 137.75,
#                 "height": 24
#               },
#               "children": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "id": "element-89",
#       "interactable": true,
#       "tagName": "span",
#       "attributes": {
#         "class": "private-icon private-icon__low",
#         "data-icon-name": "video",
#         "unique_id": "x02x",
#         "style": "color: rgb(51, 71, 91); padding-top: 2px; font-size: 16px;"
#       },
#       "text": "",
#       "rect": {
#         "bottom": 697,
#         "top": 671,
#         "left": 146,
#         "right": 162,
#         "width": 16,
#         "height": 26
#       },
#       "children": [
#         {
#           "id": "element-90",
#           "interactable": true,
#           "tagName": "span",
#           "attributes": {
#             "aria-hidden": "true",
#             "class": "UIIcon__IconContent-sc-7c34id-0 idUWwR",
#             "unique_id": "RY9b"
#           },
#           "text": "",
#           "rect": {
#             "bottom": 693,
#             "top": 677,
#             "left": 146,
#             "right": 162,
#             "width": 16,
#             "height": 16
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-90",
#       "interactable": true,
#       "tagName": "span",
#       "attributes": {
#         "aria-hidden": "true",
#         "class": "UIIcon__IconContent-sc-7c34id-0 idUWwR",
#         "unique_id": "RY9b"
#       },
#       "text": "",
#       "rect": {
#         "bottom": 693,
#         "top": 677,
#         "left": 146,
#         "right": 162,
#         "width": 16,
#         "height": 16
#       },
#       "children": []
#     },
#     {
#       "id": "element-91",
#       "interactable": true,
#       "tagName": "span",
#       "attributes": {
#         "class": "UINavItemLabel__NavItemLabel-lgq02b-0 HRrqd UINavListItem__NavItemLabel-sc-1wsoe89-3 ioExzj",
#         "unique_id": "Q84k"
#       },
#       "text": "Start overview demo",
#       "rect": {
#         "bottom": 696,
#         "top": 672,
#         "left": 170,
#         "right": 326,
#         "width": 156,
#         "height": 24
#       },
#       "children": [
#         {
#           "id": "element-92",
#           "interactable": true,
#           "tagName": "i18n-string",
#           "attributes": {
#             "data-locale-at-render": "en-in",
#             "data-key": "app.tabs.startOverviewDemo",
#             "unique_id": "whEG"
#           },
#           "text": "Start overview demo",
#           "rect": {
#             "bottom": 696,
#             "top": 672,
#             "left": 170,
#             "right": 307.75,
#             "width": 137.75,
#             "height": 24
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-92",
#       "interactable": true,
#       "tagName": "i18n-string",
#       "attributes": {
#         "data-locale-at-render": "en-in",
#         "data-key": "app.tabs.startOverviewDemo",
#         "unique_id": "whEG"
#       },
#       "text": "Start overview demo",
#       "rect": {
#         "bottom": 696,
#         "top": 672,
#         "left": 170,
#         "right": 307.75,
#         "width": 137.75,
#         "height": 24
#       },
#       "children": []
#     },
#     {
#       "id": "element-119",
#       "interactable": true,
#       "tagName": "a",
#       "attributes": {
#         "data-test-id": "task-group-link-crm_set_up_the_basics",
#         "class": "private-link uiLinkWithoutUnderline uiLinkDark",
#         "role": "button",
#         "tabindex": "0",
#         "aria-disabled": "false",
#         "unique_id": "7ogX"
#       },
#       "text": "Set up the basics",
#       "rect": {
#         "bottom": 310.2265625,
#         "top": 290.2265625,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 20
#       },
#       "children": [
#         {
#           "id": "element-120",
#           "interactable": true,
#           "tagName": "h5",
#           "attributes": {
#             "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#             "aria-level": "2",
#             "unique_id": "UveR"
#           },
#           "text": "Set up the basics",
#           "rect": {
#             "bottom": 310.2265625,
#             "top": 290.2265625,
#             "left": 476,
#             "right": 986,
#             "width": 510,
#             "height": 20
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-120",
#       "interactable": true,
#       "tagName": "h5",
#       "attributes": {
#         "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#         "aria-level": "2",
#         "unique_id": "UveR"
#       },
#       "text": "Set up the basics",
#       "rect": {
#         "bottom": 310.2265625,
#         "top": 290.2265625,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 20
#       },
#       "children": []
#     },
#     {
#       "id": "element-144",
#       "interactable": true,
#       "tagName": "a",
#       "attributes": {
#         "data-test-id": "task-group-link-sales_track_deals",
#         "class": "private-link uiLinkWithoutUnderline uiLinkDark",
#         "role": "button",
#         "tabindex": "0",
#         "aria-disabled": "false",
#         "unique_id": "qEsP"
#       },
#       "text": "Track your deals in one place",
#       "rect": {
#         "bottom": 538.078125,
#         "top": 518.078125,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 20
#       },
#       "children": [
#         {
#           "id": "element-145",
#           "interactable": true,
#           "tagName": "h5",
#           "attributes": {
#             "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#             "aria-level": "2",
#             "unique_id": "AgrR"
#           },
#           "text": "Track your deals in one place",
#           "rect": {
#             "bottom": 538.078125,
#             "top": 518.078125,
#             "left": 476,
#             "right": 986,
#             "width": 510,
#             "height": 20
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-145",
#       "interactable": true,
#       "tagName": "h5",
#       "attributes": {
#         "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#         "aria-level": "2",
#         "unique_id": "AgrR"
#       },
#       "text": "Track your deals in one place",
#       "rect": {
#         "bottom": 538.078125,
#         "top": 518.078125,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 20
#       },
#       "children": []
#     },
#     {
#       "id": "element-161",
#       "interactable": true,
#       "tagName": "a",
#       "attributes": {
#         "data-test-id": "task-group-link-sales_connect_with_leads",
#         "class": "private-link uiLinkWithoutUnderline uiLinkDark",
#         "role": "button",
#         "tabindex": "0",
#         "aria-disabled": "false",
#         "unique_id": "SRgv"
#       },
#       "text": "Quickly connect with leads",
#       "rect": {
#         "bottom": 635.078125,
#         "top": 615.078125,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 20
#       },
#       "children": [
#         {
#           "id": "element-162",
#           "interactable": true,
#           "tagName": "h5",
#           "attributes": {
#             "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#             "aria-level": "2",
#             "unique_id": "JSxT"
#           },
#           "text": "Quickly connect with leads",
#           "rect": {
#             "bottom": 635.078125,
#             "top": 615.078125,
#             "left": 476,
#             "right": 986,
#             "width": 510,
#             "height": 20
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-162",
#       "interactable": true,
#       "tagName": "h5",
#       "attributes": {
#         "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#         "aria-level": "2",
#         "unique_id": "JSxT"
#       },
#       "text": "Quickly connect with leads",
#       "rect": {
#         "bottom": 635.078125,
#         "top": 615.078125,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 20
#       },
#       "children": []
#     },
#     {
#       "id": "element-178",
#       "interactable": true,
#       "tagName": "a",
#       "attributes": {
#         "data-test-id": "task-group-link-sales_track_performance",
#         "class": "private-link uiLinkWithoutUnderline uiLinkDark",
#         "role": "button",
#         "tabindex": "0",
#         "aria-disabled": "false",
#         "unique_id": "t7oI"
#       },
#       "text": "Close deals and analyze performance",
#       "rect": {
#         "bottom": 720,
#         "top": 712.078125,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 7.921875
#       },
#       "children": [
#         {
#           "id": "element-179",
#           "interactable": true,
#           "tagName": "h5",
#           "attributes": {
#             "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#             "aria-level": "2",
#             "unique_id": "Aopu"
#           },
#           "text": "Close deals and analyze performance",
#           "rect": {
#             "bottom": 720,
#             "top": 712.078125,
#             "left": 476,
#             "right": 986,
#             "width": 510,
#             "height": 7.921875
#           },
#           "children": []
#         }
#       ]
#     },
#     {
#       "id": "element-179",
#       "interactable": true,
#       "tagName": "h5",
#       "attributes": {
#         "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0",
#         "aria-level": "2",
#         "unique_id": "Aopu"
#       },
#       "text": "Close deals and analyze performance",
#       "rect": {
#         "bottom": 720,
#         "top": 712.078125,
#         "left": 476,
#         "right": 986,
#         "width": 510,
#         "height": 7.921875
#       },
#       "children": []
#     }
#   ]
# ]

# %%
import json

async def test_mark_page_script(page):
        
        # Read the mark_page.js script
        with open("mark_page.js", "r") as f:
            mark_page_script = f.read()
        
        # Inject and execute the script
        await page.evaluate(mark_page_script)
        
        # Execute markPage() and get the results
        result = await page.evaluate("markPage()")
        
        # Print the results
        print(json.dumps(result, indent=2))
        
        # Keep the browser open for 10 seconds to visually inspect the bounding boxes
        await page.wait_for_timeout(10000)


# Example usage
await test_mark_page_script(page)
# Out:
# [
#   {
#     "x": 640,
#     "y": 22,
#     "type": "div",
#     "text": "HubSpotSearch\u2318KUpgradeUpgradeCallingMarketplacesHelpSettingscollectivai.com",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 70,
#     "type": "button",
#     "text": "Bookmarks",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 147,
#     "type": "button",
#     "text": "Workspaces",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 199,
#     "type": "button",
#     "text": "CRM",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 251,
#     "type": "button",
#     "text": "Marketing",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 303,
#     "type": "button",
#     "text": "Content",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 355,
#     "type": "button",
#     "text": "Commerce",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 407,
#     "type": "button",
#     "text": "Automations",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 459,
#     "type": "button",
#     "text": "Reporting",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 511,
#     "type": "button",
#     "text": "Data Management",
#     "ariaLabel": ""
#   },
#   {
#     "x": 32,
#     "y": 563,
#     "type": "button",
#     "text": "Library",
#     "ariaLabel": ""
#   },
#   {
#     "x": 20,
#     "y": 690,
#     "type": "svg",
#     "text": "",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 128,
#     "type": "a",
#     "text": "Marketing Guide",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 166,
#     "type": "a",
#     "text": "Sales Guide",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 204,
#     "type": "a",
#     "text": "Customer Service Guide",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 242,
#     "type": "a",
#     "text": "Content Guide",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 280,
#     "type": "a",
#     "text": "Commerce Guide",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 604,
#     "type": "a",
#     "text": "View your plan",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 644,
#     "type": "a",
#     "text": "Invite your team",
#     "ariaLabel": ""
#   },
#   {
#     "x": 236,
#     "y": 684,
#     "type": "a",
#     "text": "Start overview demo",
#     "ariaLabel": ""
#   },
#   {
#     "x": 731,
#     "y": 300.2265625,
#     "type": "a",
#     "text": "Set up the basics",
#     "ariaLabel": ""
#   },
#   {
#     "x": 731,
#     "y": 528.078125,
#     "type": "a",
#     "text": "Track your deals in one place",
#     "ariaLabel": ""
#   },
#   {
#     "x": 731,
#     "y": 625.078125,
#     "type": "a",
#     "text": "Quickly connect with leads",
#     "ariaLabel": ""
#   },
#   {
#     "x": 731,
#     "y": 722.078125,
#     "type": "a",
#     "text": "Close deals and analyze performance",
#     "ariaLabel": ""
#   }
# ]

# %%
import json

async def test_mark_page_script(page):
    # Read the goodscript.js file
    with open("goodscript.js", "r") as f:
        good_script = f.read()
    
    # Inject and execute the script
    await page.evaluate(good_script)
    
    # Execute buildTreeFromBody() and get the results
    result = await page.evaluate("buildTreeFromBody()")
    
    # Print the results
    print(json.dumps(result[1], indent=2))  # Print the resultArray (index 1 of the returned tuple)
    
    # Instead of drawing bounding boxes, let's log some information about the elements
    elements = result[0]
    print(f"Total elements found: {len(elements)}")
    
    # Print information about the first 5 elements (if available)
    for i, element in enumerate(elements[:5]):
        print(f"Element {i + 1}:")
        print(f"  Tag: {element.get('tagName')}")
        print(f"  Interactable: {element.get('interactable')}")
        print(f"  Text: {element.get('text')[:50]}...")  # First 50 characters of text
    
    # Keep the browser open for 10 seconds to allow for manual inspection if needed
    # await page.wait_for_timeout(10000)

# Example usage
await test_mark_page_script(page)
# Out:
# [
#   {
#     "id": "FdAx",
#     "frame": "main.frame",
#     "interactable": true,
#     "tagName": "body",
#     "attributes": {
#       "class": "hubspot ui-app sticky-global-toolbar hubspot-disable-focus-styles",
#       "unique_id": "FdAx",
#       "style": "--global-nav-sticky-nav-before-container-top: 0px; --global-nav-sticky-growth-dynamic-container-top: 0px; --global-nav-notifications-banner-iframe-top: 0px; --global-nav-onboarding-tours-banner-top: 0px; --global-nav-sticky-nav-top: 0px;"
#     },
#     "text": "",
#     "children": [
#       {
#         "id": "ptYR",
#         "frame": "main.frame",
#         "interactable": true,
#         "tagName": "div",
#         "attributes": {
#           "id": "hs-nav-v4",
#           "class": "nav-width-flex placeholder-nav",
#           "unique_id": "ptYR"
#         },
#         "text": "",
#         "children": [
#           {
#             "id": "bMhK",
#             "frame": "main.frame",
#             "interactable": true,
#             "tagName": "div",
#             "attributes": {
#               "id": "hs-global-toolbar-root",
#               "unique_id": "bMhK"
#             },
#             "text": "",
#             "children": [
#               {
#                 "id": "Tm2N",
#                 "frame": "main.frame",
#                 "interactable": true,
#                 "tagName": "header",
#                 "attributes": {
#                   "id": "hs-global-toolbar",
#                   "data-test-id": "hs-global-toolbar",
#                   "class": "GlobalToolbar__StyledHeader-g9am2v-3 dABJHu",
#                   "unique_id": "Tm2N"
#                 },
#                 "text": "",
#                 "children": [
#                   {
#                     "id": "dYhx",
#                     "frame": "main.frame",
#                     "interactable": true,
#                     "tagName": "div",
#                     "attributes": {
#                       "class": "hs-toolbar-logo-container",
#                       "unique_id": "dYhx"
#                     },
#                     "text": "",
#                     "children": [
#                       {
#                         "id": "nN0d",
#                         "frame": "main.frame",
#                         "interactable": true,
#                         "tagName": "a",
#                         "attributes": {
#                           "class": "GlobalToolbar__StyledLogoLink-g9am2v-4 locOFQ",
#                           "data-test-id": "home-link",
#                           "href": "/user-guide/46683262?via=home",
#                           "id": "nav-home-link",
#                           "unique_id": "nN0d"
#                         },
#                         "text": "",
#                         "children": [
#                           {
#                             "id": "p0BV",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "svg",
#                             "attributes": {
#                               "viewBox": "0 0 16 16",
#                               "height": "32px",
#                               "data-test-id": "icon-hubspot-logo",
#                               "unique_id": "p0BV"
#                             },
#                             "text": "",
#                             "children": [
#                               {
#                                 "id": "csEQ",
#                                 "frame": "main.frame",
#                                 "interactable": true,
#                                 "tagName": "path",
#                                 "attributes": {
#                                   "d": "M11.6127 10.9174C10.4763 10.9174 9.55512 10.0374 9.55512 8.95201C9.55512 7.86645 10.4763 6.98646 11.6127 6.98646C12.749 6.98646 13.6702 7.86645 13.6702 8.95201C13.6702 10.0374 12.749 10.9174 11.6127 10.9174ZM12.2286 5.16801V3.41954C12.7064 3.20397 13.041 2.74229 13.041 2.20648V2.16612C13.041 1.42664 12.4077 0.821619 11.6336 0.821619H11.5915C10.8174 0.821619 10.1841 1.42664 10.1841 2.16612V2.20648C10.1841 2.74229 10.5187 3.20416 10.9965 3.41972V5.16801C10.2852 5.27306 9.63527 5.55332 9.09927 5.96578L4.07384 2.23138C4.107 2.10973 4.1303 1.9845 4.1305 1.85286C4.13129 1.0155 3.42174 0.335606 2.54479 0.334474C1.66822 0.333532 0.956311 1.01154 0.955323 1.84909C0.954337 2.68665 1.66388 3.36654 2.54084 3.36748C2.82651 3.36786 3.09106 3.29035 3.32283 3.16436L8.26614 6.83803C7.84582 7.44418 7.59944 8.17028 7.59944 8.95201C7.59944 9.77033 7.8701 10.5274 8.32734 11.1499L6.82415 12.5861C6.7053 12.5519 6.58211 12.5282 6.45141 12.5282C5.73101 12.5282 5.14684 13.086 5.14684 13.7742C5.14684 14.4626 5.73101 15.0205 6.45141 15.0205C7.17201 15.0205 7.75599 14.4626 7.75599 13.7742C7.75599 13.6498 7.73112 13.5319 7.69538 13.4184L9.18238 11.9978C9.85738 12.4899 10.698 12.7856 11.6127 12.7856C13.8292 12.7856 15.6257 11.0692 15.6257 8.95201C15.6257 7.03531 14.1517 5.45185 12.2286 5.16801Z",
#                                   "fill": "#FF7A59",
#                                   "unique_id": "csEQ"
#                                 },
#                                 "text": "",
#                                 "children": [],
#                                 "rect": {
#                                   "bottom": 32.96953296661377,
#                                   "top": 10.022614479064941,
#                                   "left": 21.492691040039062,
#                                   "right": 44.41515350341797,
#                                   "width": 22.922462463378906,
#                                   "height": 22.946918487548828
#                                 },
#                                 "keepAllAttr": true
#                               }
#                             ],
#                             "rect": {
#                               "bottom": 34.5,
#                               "top": 9.5,
#                               "left": 20,
#                               "right": 45,
#                               "width": 25,
#                               "height": 25
#                             },
#                             "keepAllAttr": true
#                           }
#                         ],
#                         "rect": {
#                           "bottom": 40.5,
#                           "top": 3.5,
#                           "left": 12,
#                           "right": 53,
#                           "width": 41,
#                           "height": 37
#                         },
#                         "keepAllAttr": false
#                       }
#                     ],
#                     "rect": {
#                       "bottom": 44,
#                       "top": 0,
#                       "left": 12,
#                       "right": 64,
#                       "width": 52,
#                       "height": 44
#                     },
#                     "keepAllAttr": false
#                   },
#                   {
#                     "id": "dROa",
#                     "frame": "main.frame",
#                     "interactable": true,
#                     "tagName": "div",
#                     "attributes": {
#                       "class": "GlobalToolbar__SearchSectionWrapper-g9am2v-0 krjwVP",
#                       "unique_id": "dROa"
#                     },
#                     "text": "",
#                     "children": [
#                       {
#                         "id": "HMso",
#                         "frame": "main.frame",
#                         "interactable": true,
#                         "tagName": "div",
#                         "attributes": {
#                           "class": "GlobalToolbar__SearchInputWrapper-g9am2v-1 fRNvel",
#                           "unique_id": "HMso"
#                         },
#                         "text": "",
#                         "children": [
#                           {
#                             "id": "JMxH",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "div",
#                             "attributes": {
#                               "class": "StyledSearchWrapper-sc-12kwptg-0 ljqOyr",
#                               "unique_id": "JMxH"
#                             },
#                             "text": "",
#                             "children": [
#                               {
#                                 "id": "mSVT",
#                                 "frame": "main.frame",
#                                 "interactable": true,
#                                 "tagName": "form",
#                                 "attributes": {
#                                   "id": "hs-search-react",
#                                   "data-onboarding-hook": "search",
#                                   "class": "SearchForm-sc-161bglf-0 hbRWxz",
#                                   "unique_id": "mSVT"
#                                 },
#                                 "text": "",
#                                 "children": [
#                                   {
#                                     "id": "4YTG",
#                                     "frame": "main.frame",
#                                     "interactable": true,
#                                     "tagName": "div",
#                                     "attributes": {
#                                       "class": "GlobalSearchInput__StyledFlexDiv-sc-3rzpxk-0 iZsuEe",
#                                       "unique_id": "4YTG"
#                                     },
#                                     "text": "",
#                                     "children": [
#                                       {
#                                         "id": "0F00",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "button",
#                                         "attributes": {
#                                           "type": "submit",
#                                           "class": "SearchButton-sc-101koaq-0 jWVojc",
#                                           "unique_id": "0F00"
#                                         },
#                                         "text": "",
#                                         "children": [
#                                           {
#                                             "id": "OvEj",
#                                             "frame": "main.frame",
#                                             "interactable": true,
#                                             "tagName": "svg",
#                                             "attributes": {
#                                               "version": "1.1",
#                                               "xmlns": "http://www.w3.org/2000/svg",
#                                               "xmlns:xlink": "http://www.w3.org/1999/xlink",
#                                               "x": "0",
#                                               "y": "0",
#                                               "viewBox": "0 0 31 31",
#                                               "xml:space": "preserve",
#                                               "width": "14px",
#                                               "fill": "#2d3e50",
#                                               "display": "flex",
#                                               "unique_id": "OvEj"
#                                             },
#                                             "text": "",
#                                             "children": [
#                                               {
#                                                 "id": "qTkZ",
#                                                 "frame": "main.frame",
#                                                 "interactable": true,
#                                                 "tagName": "g",
#                                                 "attributes": {
#                                                   "unique_id": "qTkZ"
#                                                 },
#                                                 "text": "",
#                                                 "children": [
#                                                   {
#                                                     "id": "tzcC",
#                                                     "frame": "main.frame",
#                                                     "interactable": true,
#                                                     "tagName": "g",
#                                                     "attributes": {
#                                                       "transform": "translate(-116.000000, -3779.000000)",
#                                                       "unique_id": "tzcC"
#                                                     },
#                                                     "text": "",
#                                                     "children": [
#                                                       {
#                                                         "id": "xFiv",
#                                                         "frame": "main.frame",
#                                                         "interactable": true,
#                                                         "tagName": "path",
#                                                         "attributes": {
#                                                           "d": "M127.7,3799.4c-4.8,0-8.7-3.9-8.7-8.7c0-4.8,3.9-8.7,8.7-8.7c4.8,0,8.7,3.9,8.7,8.7 C136.4,3795.5,132.5,3799.4,127.7,3799.4 M146.1,3806.9l-9.1-9.1c1.5-2,2.4-4.4,2.4-7.1c0-6.4-5.2-11.7-11.7-11.7 c-6.4,0-11.7,5.2-11.7,11.7c0,6.4,5.2,11.7,11.7,11.7c2.7,0,5.2-0.9,7.1-2.4l9.1,9.1c0.3,0.3,0.7,0.4,1.1,0.4 c0.4,0,0.8-0.1,1.1-0.4C146.6,3808.5,146.6,3807.5,146.1,3806.9",
#                                                           "unique_id": "xFiv"
#                                                         },
#                                                         "text": "",
#                                                         "children": [],
#                                                         "rect": {
#                                                           "bottom": 27.806358337402344,
#                                                           "top": 15.999905586242676,
#                                                           "left": 84,
#                                                           "right": 95.7967758178711,
#                                                           "width": 11.796775817871094,
#                                                           "height": 11.806452751159668
#                                                         },
#                                                         "keepAllAttr": true
#                                                       }
#                                                     ],
#                                                     "rect": {
#                                                       "bottom": 27.806358337402344,
#                                                       "top": 15.999905586242676,
#                                                       "left": 84,
#                                                       "right": 95.7967758178711,
#                                                       "width": 11.796775817871094,
#                                                       "height": 11.806452751159668
#                                                     },
#                                                     "keepAllAttr": true
#                                                   }
#                                                 ],
#                                                 "rect": {
#                                                   "bottom": 27.806358337402344,
#                                                   "top": 15.999905586242676,
#                                                   "left": 84,
#                                                   "right": 95.7967758178711,
#                                                   "width": 11.796775817871094,
#                                                   "height": 11.806452751159668
#                                                 },
#                                                 "keepAllAttr": true
#                                               }
#                                             ],
#                                             "rect": {
#                                               "bottom": 28,
#                                               "top": 16,
#                                               "left": 84,
#                                               "right": 96,
#                                               "width": 12,
#                                               "height": 12
#                                             },
#                                             "keepAllAttr": true
#                                           }
#                                         ],
#                                         "rect": {
#                                           "bottom": 38,
#                                           "top": 6,
#                                           "left": 64,
#                                           "right": 96,
#                                           "width": 32,
#                                           "height": 32
#                                         },
#                                         "keepAllAttr": false
#                                       },
#                                       {
#                                         "id": "Rasx",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "input",
#                                         "attributes": {
#                                           "id": "global-search-input",
#                                           "name": "global-search-input",
#                                           "type": "search",
#                                           "data-test-id": "global-search-input-react",
#                                           "aria-label": "Search HubSpot",
#                                           "autocomplete": "off",
#                                           "minlength": "1",
#                                           "maxlength": "512",
#                                           "placeholder": "Search HubSpot",
#                                           "class": "StyledSearchInput-sc-1ki1emt-0 myxKE",
#                                           "value": "",
#                                           "unique_id": "Rasx"
#                                         },
#                                         "text": "",
#                                         "children": [],
#                                         "rect": {
#                                           "bottom": 38,
#                                           "top": 6,
#                                           "left": 96,
#                                           "right": 550,
#                                           "width": 454,
#                                           "height": 32
#                                         },
#                                         "keepAllAttr": false,
#                                         "context": "\u2318;K"
#                                       },
#                                       {
#                                         "id": "UEkw",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "label",
#                                         "attributes": {
#                                           "for": "global-search-input",
#                                           "class": "StyledShortcusHints-sc-19smeqd-0 khkQDx",
#                                           "unique_id": "UEkw"
#                                         },
#                                         "text": "",
#                                         "children": [
#                                           {
#                                             "id": "VRad",
#                                             "frame": "main.frame",
#                                             "interactable": true,
#                                             "tagName": "span",
#                                             "attributes": {
#                                               "class": "StyledKey-gze0l0-0 gLtIRF",
#                                               "unique_id": "VRad"
#                                             },
#                                             "text": "\u2318",
#                                             "children": [],
#                                             "rect": {
#                                               "bottom": 30,
#                                               "top": 14,
#                                               "left": 554,
#                                               "right": 574,
#                                               "width": 20,
#                                               "height": 16
#                                             },
#                                             "keepAllAttr": false
#                                           },
#                                           {
#                                             "id": "RXNc",
#                                             "frame": "main.frame",
#                                             "interactable": true,
#                                             "tagName": "span",
#                                             "attributes": {
#                                               "class": "StyledKey-gze0l0-0 gLtIRF",
#                                               "unique_id": "RXNc"
#                                             },
#                                             "text": "K",
#                                             "children": [],
#                                             "rect": {
#                                               "bottom": 30,
#                                               "top": 14,
#                                               "left": 578,
#                                               "right": 594,
#                                               "width": 16,
#                                               "height": 16
#                                             },
#                                             "keepAllAttr": false
#                                           }
#                                         ],
#                                         "rect": {
#                                           "bottom": 38,
#                                           "top": 6,
#                                           "left": 550,
#                                           "right": 614,
#                                           "width": 64,
#                                           "height": 32
#                                         },
#                                         "keepAllAttr": false
#                                       }
#                                     ],
#                                     "rect": {
#                                       "bottom": 38,
#                                       "top": 6,
#                                       "left": 64,
#                                       "right": 614,
#                                       "width": 550,
#                                       "height": 32
#                                     },
#                                     "keepAllAttr": false
#                                   }
#                                 ],
#                                 "rect": {
#                                   "bottom": 38,
#                                   "top": 6,
#                                   "left": 64,
#                                   "right": 614,
#                                   "width": 550,
#                                   "height": 32
#                                 },
#                                 "keepAllAttr": false
#                               }
#                             ],
#                             "rect": {
#                               "bottom": 44,
#                               "top": 0,
#                               "left": 64,
#                               "right": 614,
#                               "width": 550,
#                               "height": 44
#                             },
#                             "keepAllAttr": false
#                           }
#                         ],
#                         "rect": {
#                           "bottom": 44,
#                           "top": 0,
#                           "left": 64,
#                           "right": 614,
#                           "width": 550,
#                           "height": 44
#                         },
#                         "keepAllAttr": false
#                       }
#                     ],
#                     "rect": {
#                       "bottom": 44,
#                       "top": 0,
#                       "left": 64,
#                       "right": 749.5078125,
#                       "width": 685.5078125,
#                       "height": 44
#                     },
#                     "keepAllAttr": false
#                   },
#                   {
#                     "id": "PDq3",
#                     "frame": "main.frame",
#                     "interactable": true,
#                     "tagName": "nav",
#                     "attributes": {
#                       "class": "global-toolbar-items-container",
#                       "aria-label": "Global toolbar",
#                       "unique_id": "PDq3"
#                     },
#                     "text": "",
#                     "children": [
#                       {
#                         "id": "3w8q",
#                         "frame": "main.frame",
#                         "interactable": true,
#                         "tagName": "ul",
#                         "attributes": {
#                           "id": "hs-global-toolbar-icons",
#                           "role": "menu",
#                           "aria-orientation": "horizontal",
#                           "data-test-id": "hs-global-toolbar-icons",
#                           "class": "hs-toolbar-list",
#                           "unique_id": "3w8q"
#                         },
#                         "text": "",
#                         "children": [
#                           {
#                             "id": "L0aW",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "li",
#                             "attributes": {
#                               "role": "menuitem",
#                               "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 eqwvKd",
#                               "unique_id": "L0aW"
#                             },
#                             "text": "",
#                             "children": [
#                               {
#                                 "id": "bdXS",
#                                 "frame": "main.frame",
#                                 "interactable": true,
#                                 "tagName": "a",
#                                 "attributes": {
#                                   "class": "GlobalToolbarLink__StyledLink-sc-7orc6n-0 igcCPY",
#                                   "id": "hs-global-toolbar-suite-starter-list-item",
#                                   "data-test-id": "hs-global-toolbar-suite-starter-list-item",
#                                   "href": "https://app.hubspot.com/pricing/46683262/upgrade?upgradeSource=global-nav-bar",
#                                   "aria-label": "Upgrade",
#                                   "unique_id": "bdXS"
#                                 },
#                                 "text": "",
#                                 "children": [
#                                   {
#                                     "id": "5eVW",
#                                     "frame": "main.frame",
#                                     "interactable": true,
#                                     "tagName": "svg",
#                                     "attributes": {
#                                       "xmlns": "http://www.w3.org/2000/svg",
#                                       "viewBox": "0 0 32 32",
#                                       "width": "16px",
#                                       "height": "16px",
#                                       "fill": "#dfe3eb",
#                                       "unique_id": "5eVW"
#                                     },
#                                     "text": "",
#                                     "children": [
#                                       {
#                                         "id": "7pdT",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "path",
#                                         "attributes": {
#                                           "d": "m23.56,16.08c-.2.18-.45.28-.7.28s-.52-.1-.72-.31l-6.14-6.35-6.14,6.35c-.19.21-.45.31-.71.31s-.51-.1-.7-.28c-.4-.39-.41-1.02-.02-1.42l6.8-7.03c.21-.22.49-.32.77-.3.29-.02.57.08.78.3l6.8,7.03c.38.4.37,1.03-.02,1.42Zm-6.5,7.52v-10.04c0-.55-.45-1-1-1s-1,.45-1,1v10.04c0,.55.45,1,1,1s1-.45,1-1Zm-1.06-19.6c-6.62,0-12,5.38-12,12s5.38,12,12,12,12-5.38,12-12-5.38-12-12-12m0-2c7.73,0,14,6.27,14,14s-6.27,14-14,14S2,23.73,2,16,8.27,2,16,2h0Z",
#                                           "unique_id": "7pdT"
#                                         },
#                                         "text": "",
#                                         "children": [],
#                                         "rect": {
#                                           "bottom": 29,
#                                           "top": 15,
#                                           "left": 763.5078125,
#                                           "right": 777.5078125,
#                                           "width": 14,
#                                           "height": 14
#                                         },
#                                         "keepAllAttr": true
#                                       }
#                                     ],
#                                     "rect": {
#                                       "bottom": 30,
#                                       "top": 14,
#                                       "left": 762.5078125,
#                                       "right": 778.5078125,
#                                       "width": 16,
#                                       "height": 16
#                                     },
#                                     "keepAllAttr": true
#                                   },
#                                   {
#                                     "id": "IghN",
#                                     "frame": "main.frame",
#                                     "interactable": true,
#                                     "tagName": "span",
#                                     "attributes": {
#                                       "class": "icon-text-key",
#                                       "unique_id": "IghN"
#                                     },
#                                     "text": "Upgrade",
#                                     "children": [],
#                                     "rect": {
#                                       "bottom": 34,
#                                       "top": 10,
#                                       "left": 778.5078125,
#                                       "right": 840.484375,
#                                       "width": 61.9765625,
#                                       "height": 24
#                                     },
#                                     "keepAllAttr": false
#                                   }
#                                 ],
#                                 "rect": {
#                                   "bottom": 38,
#                                   "top": 6,
#                                   "left": 754.5078125,
#                                   "right": 848.484375,
#                                   "width": 93.9765625,
#                                   "height": 32
#                                 },
#                                 "keepAllAttr": false
#                               }
#                             ],
#                             "rect": {
#                               "bottom": 38,
#                               "top": 6,
#                               "left": 754.5078125,
#                               "right": 871.484375,
#                               "width": 116.9765625,
#                               "height": 32
#                             },
#                             "keepAllAttr": false
#                           },
#                           {
#                             "id": "fDKs",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "li",
#                             "attributes": {
#                               "role": "menuitem",
#                               "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 cdaiTj",
#                               "unique_id": "fDKs"
#                             },
#                             "text": "",
#                             "children": [
#                               {
#                                 "id": "HhOf",
#                                 "frame": "main.frame",
#                                 "interactable": true,
#                                 "tagName": "div",
#                                 "attributes": {
#                                   "data-portal-hook": "calling-remote",
#                                   "aria-haspopup": "menu",
#                                   "aria-expanded": "false",
#                                   "unique_id": "HhOf"
#                                 },
#                                 "text": "",
#                                 "children": [
#                                   {
#                                     "id": "oKmb",
#                                     "frame": "main.frame",
#                                     "interactable": true,
#                                     "tagName": "button",
#                                     "attributes": {
#                                       "aria-label": "call dropdown",
#                                       "data-selenium-test": "call-remote-toggle",
#                                       "class": "Callstyles__NewStyledToggleButton-sc-1ajwq6k-0 hokRYm",
#                                       "unique_id": "oKmb"
#                                     },
#                                     "text": "",
#                                     "children": [
#                                       {
#                                         "id": "62QY",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "div",
#                                         "attributes": {
#                                           "data-onboarding": "calling-remote",
#                                           "unique_id": "62QY",
#                                           "style": "position: relative; line-height: normal; display: flex;"
#                                         },
#                                         "text": "",
#                                         "children": [
#                                           {
#                                             "id": "AoJp",
#                                             "frame": "main.frame",
#                                             "interactable": true,
#                                             "tagName": "svg",
#                                             "attributes": {
#                                               "class": "icon",
#                                               "width": "14px",
#                                               "height": "14px",
#                                               "viewBox": "0 0 32 32",
#                                               "fill": "#dfe3eb",
#                                               "unique_id": "AoJp"
#                                             },
#                                             "text": "",
#                                             "children": [
#                                               {
#                                                 "id": "w9Xs",
#                                                 "frame": "main.frame",
#                                                 "interactable": true,
#                                                 "tagName": "path",
#                                                 "attributes": {
#                                                   "d": "m22.63,29.99c-1.01,0-2.09-.16-3.24-.48-1.11-.31-2.13-.69-3.11-1.16-.03-.02-.06-.03-.1-.05-2.74-1.36-5.18-3.13-7.27-5.26-2.17-2.13-3.94-4.59-5.28-7.31l-.08-.19c-.19-.37-.37-.8-.58-1.37-1.55-4.11-1.23-7.68.87-9.78l1.53-1.53c1.17-1.16,3.19-1.16,4.36,0l4.07,4.07c.58.58.9,1.36.9,2.19s-.32,1.6-.91,2.19l-2.97,2.97c-.1.1-.15.23-.15.36s.05.26.15.36l6.12,6.12c.19.19.53.19.72,0l2.97-2.97c1.17-1.17,3.21-1.17,4.37,0l4.09,4.08c.58.58.91,1.36.91,2.19s-.32,1.6-.9,2.19l-1.54,1.53c-1.23,1.23-2.92,1.86-4.92,1.86Zm-5.36-3.24c.83.39,1.67.7,2.62.96,2.74.77,4.99.45,6.34-.9l1.54-1.53c.23-.23.36-.54.36-.86s-.13-.63-.36-.87l-4.09-4.08c-.46-.46-1.27-.46-1.73,0l-2.97,2.97c-.9.89-2.46.9-3.36,0l-6.12-6.12c-.45-.45-.7-1.04-.7-1.68s.25-1.23.7-1.68l2.97-2.97c.23-.23.36-.54.36-.87s-.13-.64-.36-.87l-4.07-4.07c-.46-.45-1.26-.45-1.72,0l-1.52,1.52h0c-1.56,1.56-1.72,4.4-.44,7.8.19.5.35.88.53,1.23l.09.19c1.23,2.5,2.88,4.79,4.91,6.77,2,2.04,4.34,3.71,6.97,5,.02.01.05.02.07.04ZM4.5,5.06h0,0Z",
#                                                   "unique_id": "w9Xs"
#                                                 },
#                                                 "text": "",
#                                                 "children": [],
#                                                 "rect": {
#                                                   "bottom": 28.125003814697266,
#                                                   "top": 15.870626449584961,
#                                                   "left": 890.3593139648438,
#                                                   "right": 902.609375,
#                                                   "width": 12.25006103515625,
#                                                   "height": 12.254377365112305
#                                                 },
#                                                 "keepAllAttr": true
#                                               }
#                                             ],
#                                             "rect": {
#                                               "bottom": 29,
#                                               "top": 15,
#                                               "left": 889.484375,
#                                               "right": 903.484375,
#                                               "width": 14,
#                                               "height": 14
#                                             },
#                                             "keepAllAttr": true
#                                           }
#                                         ],
#                                         "rect": {
#                                           "bottom": 29,
#                                           "top": 15,
#                                           "left": 889.484375,
#                                           "right": 903.484375,
#                                           "width": 14,
#                                           "height": 14
#                                         },
#                                         "keepAllAttr": false
#                                       }
#                                     ],
#                                     "rect": {
#                                       "bottom": 37,
#                                       "top": 7,
#                                       "left": 881.484375,
#                                       "right": 911.484375,
#                                       "width": 30,
#                                       "height": 30
#                                     },
#                                     "keepAllAttr": false
#                                   }
#                                 ],
#                                 "rect": {
#                                   "bottom": 37,
#                                   "top": 7,
#                                   "left": 881.484375,
#                                   "right": 911.484375,
#                                   "width": 30,
#                                   "height": 30
#                                 },
#                                 "keepAllAttr": false
#                               }
#                             ],
#                             "rect": {
#                               "bottom": 37,
#                               "top": 7,
#                               "left": 881.484375,
#                               "right": 911.484375,
#                               "width": 30,
#                               "height": 30
#                             },
#                             "keepAllAttr": false
#                           },
#                           {
#                             "id": "aoV0",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "li",
#                             "attributes": {
#                               "data-portal-hook": "marketplace-menu",
#                               "role": "menuitem",
#                               "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 gFuatf",
#                               "unique_id": "aoV0"
#                             },
#                             "text": "",
#                             "children": [
#                               {
#                                 "id": "5YNS",
#                                 "frame": "main.frame",
#                                 "interactable": true,
#                                 "tagName": "button",
#                                 "attributes": {
#                                   "class": "Marketplace__StyledMenuButton-sc-6d3dsf-0 cQeNEB",
#                                   "id": "hs-global-toolbar-marketplace-list-item",
#                                   "aria-haspopup": "true",
#                                   "data-test-id": "hs-global-toolbar-marketplace-list-item",
#                                   "aria-label": "Marketplaces",
#                                   "unique_id": "5YNS"
#                                 },
#                                 "text": "",
#                                 "children": [
#                                   {
#                                     "id": "ZSGg",
#                                     "frame": "main.frame",
#                                     "interactable": true,
#                                     "tagName": "svg",
#                                     "attributes": {
#                                       "xmlns": "http://www.w3.org/2000/svg",
#                                       "viewBox": "0 0 32 32",
#                                       "width": "16px",
#                                       "height": "16px",
#                                       "fill": "#dfe3eb",
#                                       "unique_id": "ZSGg"
#                                     },
#                                     "text": "",
#                                     "children": [
#                                       {
#                                         "id": "WWZ9",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "path",
#                                         "attributes": {
#                                           "d": "m12.36,16.23c-1.72,0-2.92-.96-3.66-1.83-.72.78-1.86,1.6-3.63,1.55-1.44-.03-2.2-.66-2.58-1.18-.96-1.31-.49-3.11-.43-3.31L4.47,2.91c.12-.43.51-.73.96-.73h21.24c.46,0,.86.31.97.75l2.32,9.15c.04.14.47,1.71-.39,2.85-.34.46-1.01,1-2.27,1-1.91,0-3.14-.74-3.9-1.48-.63.79-1.66,1.59-3.24,1.59-1.9,0-3.15-.71-3.91-1.52-.79.9-2.06,1.71-3.9,1.71Zm-3.64-4.6h0c.39,0,.75.23.91.59,0,.02.95,2.01,2.73,2.01,2.24,0,2.9-1.77,2.97-1.97.14-.43.55-.7,1.01-.69.45.03.83.34.92.79.04.16.49,1.68,2.91,1.68,1.59,0,2.16-1.68,2.18-1.75.13-.4.5-.68.93-.69.42,0,.81.24.96.64.02.06.72,1.69,3.07,1.69.24,0,.55-.03.67-.2.19-.25.13-.86.06-1.13l-2.14-8.42H6.19l-2.2,7.84c-.07.27-.21,1.14.12,1.58.17.23.51.35,1.01.36.02,0,.04,0,.06,0,1.82,0,2.59-1.66,2.62-1.74.16-.36.52-.59.91-.59Zm18.88,17.2v-10.56c0-.55-.45-1-1-1s-1,.45-1,1v9.56h-8.21v-7.16c0-.55-.45-1-1-1h-5.93c-.55,0-1,.45-1,1v7.16h-3.36v-9.56c0-.55-.45-1-1-1s-1,.45-1,1v10.56c0,.55.45,1,1,1h5.36c.55,0,1-.45,1-1v-7.16h3.93v7.16c0,.55.45,1,1,1h10.21c.55,0,1-.45,1-1Z",
#                                           "unique_id": "WWZ9"
#                                         },
#                                         "text": "",
#                                         "children": [],
#                                         "rect": {
#                                           "bottom": 28.915000915527344,
#                                           "top": 15.09000015258789,
#                                           "left": 930.4305419921875,
#                                           "right": 944.5357055664062,
#                                           "width": 14.10516357421875,
#                                           "height": 13.825000762939453
#                                         },
#                                         "keepAllAttr": true
#                                       }
#                                     ],
#                                     "rect": {
#                                       "bottom": 30,
#                                       "top": 14,
#                                       "left": 929.484375,
#                                       "right": 945.484375,
#                                       "width": 16,
#                                       "height": 16
#                                     },
#                                     "keepAllAttr": true
#                                   }
#                                 ],
#                                 "rect": {
#                                   "bottom": 38,
#                                   "top": 6,
#                                   "left": 921.484375,
#                                   "right": 953.484375,
#                                   "width": 32,
#                                   "height": 32
#                                 },
#                                 "keepAllAttr": false
#                               }
#                             ],
#                             "rect": {
#                               "bottom": 38,
#                               "top": 6,
#                               "left": 921.484375,
#                               "right": 953.484375,
#                               "width": 32,
#                               "height": 32
#                             },
#                             "keepAllAttr": false
#                           },
#                           {
#                             "id": "UCjc",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "li",
#                             "attributes": {
#                               "role": "menuitem",
#                               "class": "GlobalToolbarItem__StyledListItem-d26ajz-0 cdaiTj",
#                               "unique_id": "UCjc"
#                             },
#                             "text": "",
# ...
#                                               }
#                                             ],
#                                             "rect": null,
#                                             "keepAllAttr": false
#                                           }
#                                         ],
#                                         "rect": null,
#                                         "keepAllAttr": false
#                                       },
#                                       {
#                                         "id": "w05U",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "hr",
#                                         "attributes": {
#                                           "class": "HR__StyledHR-sc-1glyzww-0 ekapqf LearnMoreCard__Divider-sc-1ygal91-1 fBWzLd",
#                                           "unique_id": "w05U"
#                                         },
#                                         "text": "",
#                                         "children": [],
#                                         "rect": null,
#                                         "keepAllAttr": false
#                                       }
#                                     ],
#                                     "rect": null,
#                                     "keepAllAttr": false
#                                   },
#                                   {
#                                     "id": "i8Gc",
#                                     "frame": "main.frame",
#                                     "interactable": true,
#                                     "tagName": "div",
#                                     "attributes": {
#                                       "data-test-id": "learn-more-card-item",
#                                       "class": "LearnMoreCard__LearnMoreCardItem-sc-1ygal91-0 iBmxKx",
#                                       "unique_id": "i8Gc"
#                                     },
#                                     "text": "",
#                                     "children": [
#                                       {
#                                         "id": "R2Tx",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "span",
#                                         "attributes": {
#                                           "class": "private-icon private-icon__high",
#                                           "data-icon-name": "marketplace",
#                                           "unique_id": "R2Tx",
#                                           "style": "color: rgb(153, 172, 194); justify-self: center; font-size: 32px;"
#                                         },
#                                         "text": "",
#                                         "children": [
#                                           {
#                                             "id": "uurx",
#                                             "frame": "main.frame",
#                                             "interactable": true,
#                                             "tagName": "span",
#                                             "attributes": {
#                                               "aria-hidden": "true",
#                                               "class": "UIIcon__IconContent-sc-7c34id-0 fHFsIf",
#                                               "unique_id": "uurx"
#                                             },
#                                             "text": "",
#                                             "children": [],
#                                             "rect": null,
#                                             "keepAllAttr": false
#                                           }
#                                         ],
#                                         "rect": null,
#                                         "keepAllAttr": false
#                                       },
#                                       {
#                                         "id": "8FDF",
#                                         "frame": "main.frame",
#                                         "interactable": true,
#                                         "tagName": "div",
#                                         "attributes": {
#                                           "unique_id": "8FDF"
#                                         },
#                                         "text": "",
#                                         "children": [
#                                           {
#                                             "id": "r0sE",
#                                             "frame": "main.frame",
#                                             "interactable": true,
#                                             "tagName": "a",
#                                             "attributes": {
#                                               "class": "private-link uiLinkWithoutUnderline uiLinkDark",
#                                               "href": "https://ecosystem.hubspot.com/marketplace/apps/sales",
#                                               "rel": "noopener noreferrer",
#                                               "tabindex": "0",
#                                               "aria-disabled": "false",
#                                               "unique_id": "r0sE"
#                                             },
#                                             "text": "",
#                                             "children": [
#                                               {
#                                                 "id": "Rkgv",
#                                                 "frame": "main.frame",
#                                                 "interactable": true,
#                                                 "tagName": "h5",
#                                                 "attributes": {
#                                                   "class": "Heading-vqu5ix-0 H5-sc-1x0gg8o-0 cPuYpV m-bottom-0 display-inline",
#                                                   "aria-level": "2",
#                                                   "unique_id": "Rkgv"
#                                                 },
#                                                 "text": "",
#                                                 "children": [
#                                                   {
#                                                     "id": "nDTf",
#                                                     "frame": "main.frame",
#                                                     "interactable": true,
#                                                     "tagName": "i18n-string",
#                                                     "attributes": {
#                                                       "data-locale-at-render": "en-in",
#                                                       "data-key": "sales.learnMore.ctas.app-marketplace-sales",
#                                                       "unique_id": "nDTf"
#                                                     },
#                                                     "text": "Connect sales apps from the App Marketplace",
#                                                     "children": [],
#                                                     "rect": null,
#                                                     "keepAllAttr": false
#                                                   }
#                                                 ],
#                                                 "rect": null,
#                                                 "keepAllAttr": false
#                                               },
#                                               {
#                                                 "id": "LqEp",
#                                                 "frame": "main.frame",
#                                                 "interactable": true,
#                                                 "tagName": "span",
#                                                 "attributes": {
#                                                   "aria-label": "Link opens in a new window",
#                                                   "role": "img",
#                                                   "class": "private-icon private-icon__low UILink__DefaultExternalIcon-sc-68jp7l-0 jeEug private-link--external__icon",
#                                                   "data-icon-name": "externalLink",
#                                                   "unique_id": "LqEp"
#                                                 },
#                                                 "text": "",
#                                                 "children": [
#                                                   {
#                                                     "id": "td6m",
#                                                     "frame": "main.frame",
#                                                     "interactable": true,
#                                                     "tagName": "span",
#                                                     "attributes": {
#                                                       "aria-hidden": "true",
#                                                       "class": "UIIcon__IconContent-sc-7c34id-0 ZsJQx",
#                                                       "unique_id": "td6m"
#                                                     },
#                                                     "text": "",
#                                                     "children": [],
#                                                     "rect": null,
#                                                     "keepAllAttr": false
#                                                   }
#                                                 ],
#                                                 "rect": null,
#                                                 "keepAllAttr": false
#                                               }
#                                             ],
#                                             "rect": null,
#                                             "keepAllAttr": false
#                                           }
#                                         ],
#                                         "rect": null,
#                                         "keepAllAttr": false
#                                       }
#                                     ],
#                                     "rect": null,
#                                     "keepAllAttr": false
#                                   }
#                                 ],
#                                 "rect": null,
#                                 "keepAllAttr": false
#                               }
#                             ],
#                             "rect": null,
#                             "keepAllAttr": false
#                           },
#                           {
#                             "id": "jJ1c",
#                             "frame": "main.frame",
#                             "interactable": true,
#                             "tagName": "div",
#                             "attributes": {
#                               "class": "EnrollmentFooter__EnrollmentFooterPlaceholder-sc-1oypy2z-0 TXLgL enrollment-placeholder",
#                               "unique_id": "jJ1c"
#                             },
#                             "text": "",
#                             "children": [],
#                             "rect": null,
#                             "keepAllAttr": false
#                           }
#                         ],
#                         "rect": {
#                           "bottom": 720,
#                           "top": 44,
#                           "left": 375,
#                           "right": 1225,
#                           "width": 850,
#                           "height": 676
#                         },
#                         "keepAllAttr": false
#                       }
#                     ],
#                     "rect": {
#                       "bottom": 720,
#                       "top": 44,
#                       "left": 64,
#                       "right": 1280,
#                       "width": 1216,
#                       "height": 676
#                     },
#                     "keepAllAttr": false
#                   }
#                 ],
#                 "rect": {
#                   "bottom": 720,
#                   "top": 44,
#                   "left": 64,
#                   "right": 1280,
#                   "width": 1216,
#                   "height": 676
#                 },
#                 "keepAllAttr": false
#               }
#             ],
#             "rect": {
#               "bottom": 720,
#               "top": 44,
#               "left": 64,
#               "right": 1280,
#               "width": 1216,
#               "height": 676
#             },
#             "keepAllAttr": false
#           }
#         ],
#         "rect": {
#           "bottom": 720,
#           "top": 44,
#           "left": 64,
#           "right": 1280,
#           "width": 1216,
#           "height": 676
#         },
#         "keepAllAttr": false
#       },
#       {
#         "id": "pv0v",
#         "frame": "main.frame",
#         "interactable": true,
#         "tagName": "svg",
#         "attributes": {
#           "data-test-id": "hs-nav-onboarding-highlight",
#           "class": "OnboardingHighlight__StyledSvg-sc-15bhxad-0 ieXljv",
#           "unique_id": "pv0v"
#         },
#         "text": "",
#         "children": [],
#         "rect": {
#           "bottom": 720,
#           "top": 0,
#           "left": 0,
#           "right": 1280,
#           "width": 1280,
#           "height": 720
#         },
#         "keepAllAttr": true
#       }
#     ],
#     "rect": {
#       "bottom": 720,
#       "top": 0,
#       "left": 0,
#       "right": 1280,
#       "width": 1280,
#       "height": 720
#     },
#     "keepAllAttr": false
#   },
#   {
#     "id": "VGvI",
#     "frame": "main.frame",
#     "interactable": false,
#     "tagName": "iframe",
#     "attributes": {
#       "id": "calling-shared-worker-versioning-embed",
#       "src": "https://app.hubspot.com/calling-cross-tab-embed/46683262/embed?connectionType=EXTERNAL&origin=https%253A%252F%252Fapp.hubspot.com&connectionId=callingConnectionId_9db564b3-3d1e-4cb5-95dd-93b5aed0ebe3",
#       "style": "top: 0px; height: 0px; width: 0px; display: none; position: fixed;",
#       "unique_id": "VGvI"
#     },
#     "text": "",
#     "children": [],
#     "rect": null,
#     "keepAllAttr": false
#   },
#   {
#     "id": "oidL",
#     "frame": "main.frame",
#     "interactable": false,
#     "tagName": "div",
#     "attributes": {
#       "id": "live-notifications-shadow",
#       "unique_id": "oidL",
#       "style": "position: fixed; top: 48px; right: 10px; z-index: 1000; transition: right 0.25s ease-in-out;"
#     },
#     "text": "",
#     "children": [],
#     "rect": {
#       "bottom": 56,
#       "top": 48,
#       "left": 1254,
#       "right": 1270,
#       "width": 16,
#       "height": 8
#     },
#     "keepAllAttr": false
#   },
#   {
#     "id": "AqNC",
#     "frame": "main.frame",
#     "interactable": false,
#     "tagName": "iframe",
#     "attributes": {
#       "id": "live-notifications-shared-worker-versioning-embed",
#       "src": "https://app.hubspot.com/live-notifications-embed/46683262/embed?parentOrigin=https%253A%252F%252Fapp.hubspot.com&connectionId=LIVE_NOTIFICATIONS_e482b633-7136-4f37-a9fe-11af58657052",
#       "unique_id": "AqNC",
#       "style": "top: 0px; height: 0px; width: 0px; display: none; position: fixed;"
#     },
#     "text": "",
#     "children": [],
#     "rect": null,
#     "keepAllAttr": false
#   }
# ]
# Total elements found: 313
# Element 1:
#   Tag: body
#   Interactable: True
#   Text: ...
# Element 2:
#   Tag: div
#   Interactable: True
#   Text: ...
# Element 3:
#   Tag: div
#   Interactable: True
#   Text: ...
# Element 4:
#   Tag: header
#   Interactable: True
#   Text: ...
# Element 5:
#   Tag: div
#   Interactable: True
#   Text: ...

# %%
import json

async def test_mark_page_script(page):
    # Read the goodscript.js file
    with open("goodscript.js", "r") as f:
        good_script = f.read()
    
    # Inject and execute the script
    await page.evaluate(good_script)
    
    # Execute buildTreeFromBody() and get the results
    result = await page.evaluate("buildTreeFromBody()")
    
    elements = result[0]
    print(f"Total elements found: {len(elements)}")
    
    # Filter for interactable elements
    interactable_elements = [elem for elem in elements if elem.get('interactable')]
    print(f"Interactable elements found: {len(interactable_elements)}")
    
    # Print information about the first 5 interactable elements
    for i, element in enumerate(interactable_elements[:5]):
        print(f"Interactable Element {i + 1}:")
        print(f"  Tag: {element.get('tagName')}")
        print(f"  Text: {element.get('text')[:50]}...")  # First 50 characters of text
        print(f"  Rect: {element.get('rect')}")
    
    # Draw bounding boxes for interactable elements
    await page.evaluate("""
        (elements) => {
            console.log('Drawing bounding boxes for', elements.length, 'elements');
            drawBoundingBoxes(elements);
            console.log('Bounding boxes drawn');
        }
    """, interactable_elements)
    
    # Check if bounding boxes were created
    bounding_box_count = await page.evaluate("""
        () => {
            const container = document.querySelector('#boundingBoxContainer');
            return container ? container.childElementCount : 0;
        }
    """)
    print(f"Number of bounding boxes created: {bounding_box_count}")
    
    # Keep the browser open for 10 seconds to allow for manual inspection
    await page.wait_for_timeout(10000)
    
    # Remove bounding boxes
    await page.evaluate("removeBoundingBoxes()")

# Example usage
await test_mark_page_script(page)
# Out:
# Total elements found: 313
# Interactable elements found: 310
# Interactable Element 1:
#   Tag: body
#   Text: ...
#   Rect: {'bottom': 720, 'top': 0, 'left': 0, 'right': 1280, 'width': 1280, 'height': 720}
# Interactable Element 2:
#   Tag: div
#   Text: ...
#   Rect: {'bottom': 44, 'top': 0, 'left': 0, 'right': 1280, 'width': 1280, 'height': 44}
# Interactable Element 3:
#   Tag: div
#   Text: ...
#   Rect: {'bottom': 44, 'top': 0, 'left': 0, 'right': 1280, 'width': 1280, 'height': 44}
# Interactable Element 4:
#   Tag: header
#   Text: ...
#   Rect: {'bottom': 44, 'top': 0, 'left': 0, 'right': 1280, 'width': 1280, 'height': 44}
# Interactable Element 5:
#   Tag: div
#   Text: ...
#   Rect: {'bottom': 44, 'top': 0, 'left': 12, 'right': 64, 'width': 52, 'height': 44}
# Number of bounding boxes created: 254
